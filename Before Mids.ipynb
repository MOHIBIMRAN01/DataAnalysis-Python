# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\pc\Desktop\movies_initial - movies_initial.csv")

# %%
df
# Out:
#         imdbID                                   title  year     rating  \
# 0            1                              Carmencita  1894  NOT RATED
# 1            5                        Blacksmith Scene  1893    UNRATED
# 2            3                          Pauvre Pierrot  1892        NaN
# 3            8  Edison Kinetoscopic Record of a Sneeze  1894        NaN
# 4           10   Employees Leaving the Lumi�re Factory  1895        NaN
# ...        ...                                     ...   ...        ...
# 46009  5005684                       The New Classmate  2015        NaN
# 46010  5013056      Untitled Christopher Nolan Project  2017        NaN
# 46011  5013980                  Die Turnschuh-Giganten  2016        NaN
# 46012  5016760                The Monster of Mangatiti  2015        NaN
# 46013  5023260                           The Last Word  2016        NaN
#
#       runtime                     genre    released              director  \
# ...

# %%
df.columns
# Out:
# Index(['imdbID', 'title', 'year', 'rating', 'runtime', 'genre', 'released',
#        'director', 'writer', 'cast', 'metacritic', 'imdbRating', 'imdbVotes',
#        'poster', 'plot', 'fullplot', 'language', 'country', 'awards',
#        'lastupdated', 'type'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46014 entries, 0 to 46013
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdbID       46014 non-null  int64
#  1   title        46014 non-null  object
#  2   year         46014 non-null  object
#  3   rating       24629 non-null  object
#  4   runtime      43377 non-null  object
#  5   genre        45615 non-null  object
#  6   released     43002 non-null  object
#  7   director     45409 non-null  object
#  8   writer       42942 non-null  object
#  9   cast         44928 non-null  object
#  10  metacritic   9401 non-null   float64
#  11  imdbRating   44300 non-null  float64
#  12  imdbVotes    44299 non-null  float64
#  13  poster       35798 non-null  object
#  14  plot         42161 non-null  object
#  15  fullplot     41421 non-null  object
#  16  language     44899 non-null  object
#  17  country      45830 non-null  object
# ...

# %%
df.describe()
# Out:
#              imdbID   metacritic    imdbRating     imdbVotes
# count  4.601400e+04  9401.000000  44300.000000  4.429900e+04
# mean   8.552062e+05    56.896288      6.381454  1.180055e+04
# std    1.141979e+06    17.715373      1.183113  4.934499e+04
# min    1.000000e+00     1.000000      1.100000  5.000000e+00
# 25%    8.165750e+04    45.000000      5.800000  3.260000e+02
# 50%    2.524875e+05    58.000000      6.600000  9.990000e+02
# 75%    1.370868e+06    70.000000      7.200000  3.829000e+03
# max    5.023260e+06   100.000000      9.600000  1.521105e+06

# %%
df.head()
# Out:
#    imdbID                                   title  year     rating runtime  \
# 0       1                              Carmencita  1894  NOT RATED   1 min
# 1       5                        Blacksmith Scene  1893    UNRATED   1 min
# 2       3                          Pauvre Pierrot  1892        NaN   4 min
# 3       8  Edison Kinetoscopic Record of a Sneeze  1894        NaN   1 min
# 4      10   Employees Leaving the Lumi�re Factory  1895        NaN   1 min
#
#                       genre    released              director writer  \
# 0        Documentary, Short         NaN  William K.L. Dickson    NaN
# 1                     Short  1893-05-09  William K.L. Dickson    NaN
# 2  Animation, Comedy, Short  1892-10-28         �mile Reynaud    NaN
# 3        Documentary, Short  1894-01-09  William K.L. Dickson    NaN
# 4        Documentary, Short  1895-03-22         Louis Lumi�re    NaN
#
#                        cast  ...  imdbRating  imdbVotes  \
# ...

# %%
data = df['imdbID']
data.head()
# Out:
# 0     1
# 1     5
# 2     3
# 3     8
# 4    10
# Name: imdbID, dtype: int64

# %%
data1 = data.iloc[3]
data1
# Out:
# 8

# %%
data2 = data.iloc[[2,3,4]]
data2
# Out:
# 2     3
# 3     8
# 4    10
# Name: imdbID, dtype: int64

# %%
data3 = data.iloc[0:20:3]
data3
# Out:
# 0       1
# 3       8
# 6      14
# 9      70
# 12    131
# 15    192
# 18    242
# Name: imdbID, dtype: int64

# %%
data_Con = df.loc[df['country']=='USA','plot']
data_Con
# Out:
# 0        Performing on what looks like a small wooden s...
# 1        Three men hammer on an anvil and pass a bottle...
# 3        A man (Thomas Edison's assistant) takes a pinc...
# 15       Dancer Ella Lola dances a routine based on the...
# 23       A most perfect picture of the Pan-American Exp...
#                                ...
# 45995                                                  NaN
# 46001                                                  NaN
# 46003                                                  NaN
# 46006    Musician Jonny Greenwood travels to Rajasthan,...
# 46013                                                  NaN
# Name: plot, Length: 20589, dtype: object

# %%
imd_id = [1,3,7]
data4 = df.loc[df['imdbID'].isin(imd_id)]
data4
# Out:
#        imdbID           title  year     rating runtime  \
# 0           1      Carmencita  1894  NOT RATED   1 min
# 2           3  Pauvre Pierrot  1892        NaN   4 min
# 22199       1      Carmencita  1894  NOT RATED   1 min
#
#                           genre    released              director writer  \
# 0            Documentary, Short         NaN  William K.L. Dickson    NaN
# 2      Animation, Comedy, Short  1892-10-28         �mile Reynaud    NaN
# 22199        Documentary, Short         NaN  William K.L. Dickson    NaN
#
#              cast  ...  imdbRating  imdbVotes  \
# 0      Carmencita  ...         5.9     1032.0
# 2             NaN  ...         6.7      566.0
# 22199  Carmencita  ...         5.9     1035.0
#
#                                                   poster  \
# 0      https://m.media-amazon.com/images/M/MV5BMjAzND...
# 2                                                    NaN
# 22199  https://m.media-amazon.com/images/M/MV5BMjAzND...
#
# ...

# %%
d = df.loc[df['country'].isin(['USA'])]
d
# Out:
#         imdbID                                      title  year     rating  \
# 0            1                                 Carmencita  1894  NOT RATED
# 1            5                           Blacksmith Scene  1893    UNRATED
# 3            8     Edison Kinetoscopic Record of a Sneeze  1894        NaN
# 15         192                     Ella Lola, a la Trilby  1898        NaN
# 23         364             Panorama of Esplanade by Night  1901        NaN
# ...        ...                                        ...   ...        ...
# 45995  4981636  Middle School: The Worst Years of My Life  2016        NaN
# 46001  4991652                                     Camino  2016        NaN
# 46003  4991512                                     Tramps  2015        NaN
# 46006  4995590                                     Junjun  2015        NaN
# 46013  5023260                              The Last Word  2016        NaN
#
# ...

# %%
df.set_index('imdbID')
# Out:
#                                           title  year     rating runtime  \
# imdbID
# 1                                    Carmencita  1894  NOT RATED   1 min
# 5                              Blacksmith Scene  1893    UNRATED   1 min
# 3                                Pauvre Pierrot  1892        NaN   4 min
# 8        Edison Kinetoscopic Record of a Sneeze  1894        NaN   1 min
# 10        Employees Leaving the Lumi�re Factory  1895        NaN   1 min
# ...                                         ...   ...        ...     ...
# 5005684                       The New Classmate  2015        NaN     NaN
# 5013056      Untitled Christopher Nolan Project  2017        NaN     NaN
# 5013980                  Die Turnschuh-Giganten  2016        NaN     NaN
# 5016760                The Monster of Mangatiti  2015        NaN     NaN
# 5023260                           The Last Word  2016        NaN     NaN
#
#                             genre    released              director  \
# imdbID
# ...

# %%
df.iloc[2]
# Out:
# imdbID                                                         3
# title                                             Pauvre Pierrot
# year                                                        1892
# rating                                                       NaN
# runtime                                                    4 min
# genre                                   Animation, Comedy, Short
# released                                              1892-10-28
# director                                           �mile Reynaud
# writer                                                       NaN
# cast                                                         NaN
# metacritic                                                   NaN
# imdbRating                                                   6.7
# imdbVotes                                                  566.0
# poster                                                       NaN
# ...

# %%
df.iloc[[2,3,4]]
# Out:
#    imdbID                                   title  year rating runtime  \
# 2       3                          Pauvre Pierrot  1892    NaN   4 min
# 3       8  Edison Kinetoscopic Record of a Sneeze  1894    NaN   1 min
# 4      10   Employees Leaving the Lumi�re Factory  1895    NaN   1 min
#
#                       genre    released              director writer  \
# 2  Animation, Comedy, Short  1892-10-28         �mile Reynaud    NaN
# 3        Documentary, Short  1894-01-09  William K.L. Dickson    NaN
# 4        Documentary, Short  1895-03-22         Louis Lumi�re    NaN
#
#        cast  ...  imdbRating  imdbVotes  poster  \
# 2       NaN  ...         6.7      566.0     NaN
# 3  Fred Ott  ...         5.9      988.0     NaN
# 4       NaN  ...         6.9     3469.0     NaN
#
#                                                 plot  \
# 2  One night, Arlequin come to see his lover Colo...
# 3  A man (Thomas Edison's assistant) takes a pinc...
# ...

# %%
df.iloc[1:3]
# Out:
#    imdbID             title  year   rating runtime                     genre  \
# 1       5  Blacksmith Scene  1893  UNRATED   1 min                     Short
# 2       3    Pauvre Pierrot  1892      NaN   4 min  Animation, Comedy, Short
#
#      released              director writer                      cast  ...  \
# 1  1893-05-09  William K.L. Dickson    NaN  Charles Kayser, John Ott  ...
# 2  1892-10-28         �mile Reynaud    NaN                       NaN  ...
#
#    imdbRating  imdbVotes  poster  \
# 1         6.2     1189.0     NaN
# 2         6.7      566.0     NaN
#
#                                                 plot  \
# 1  Three men hammer on an anvil and pass a bottle...
# 2  One night, Arlequin come to see his lover Colo...
#
#                                             fullplot language country  awards  \
# 1  A stationary camera looks at a large anvil wit...      NaN     USA  1 win.
# 2  One night, Arlequin come to see his lover Colo...      NaN  France     NaN
#
# ...

# %%
df.loc[2:4]
# Out:
#    imdbID                                   title  year rating runtime  \
# 2       3                          Pauvre Pierrot  1892    NaN   4 min
# 3       8  Edison Kinetoscopic Record of a Sneeze  1894    NaN   1 min
# 4      10   Employees Leaving the Lumi�re Factory  1895    NaN   1 min
#
#                       genre    released              director writer  \
# 2  Animation, Comedy, Short  1892-10-28         �mile Reynaud    NaN
# 3        Documentary, Short  1894-01-09  William K.L. Dickson    NaN
# 4        Documentary, Short  1895-03-22         Louis Lumi�re    NaN
#
#        cast  ...  imdbRating  imdbVotes  poster  \
# 2       NaN  ...         6.7      566.0     NaN
# 3  Fred Ott  ...         5.9      988.0     NaN
# 4       NaN  ...         6.9     3469.0     NaN
#
#                                                 plot  \
# 2  One night, Arlequin come to see his lover Colo...
# 3  A man (Thomas Edison's assistant) takes a pinc...
# ...

# %%
alll = df.iloc[:8,:9]
alll
# Out:
#    imdbID                                   title  year     rating runtime  \
# 0       1                              Carmencita  1894  NOT RATED   1 min
# 1       5                        Blacksmith Scene  1893    UNRATED   1 min
# 2       3                          Pauvre Pierrot  1892        NaN   4 min
# 3       8  Edison Kinetoscopic Record of a Sneeze  1894        NaN   1 min
# 4      10   Employees Leaving the Lumi�re Factory  1895        NaN   1 min
# 5      12                  The Arrival of a Train  1896        NaN   1 min
# 6      14           Tables Turned on the Gardener  1895        NaN   1 min
# 7      29                           Baby's Dinner  1895        NaN   1 min
#
#                       genre    released                        director writer
# 0        Documentary, Short         NaN            William K.L. Dickson    NaN
# 1                     Short  1893-05-09            William K.L. Dickson    NaN
# ...

# %%
loc = df.loc[1:6,['rating','released','director']]
loc
# Out:
#     rating    released                        director
# 1  UNRATED  1893-05-09            William K.L. Dickson
# 2      NaN  1892-10-28                   �mile Reynaud
# 3      NaN  1894-01-09            William K.L. Dickson
# 4      NaN  1895-03-22                   Louis Lumi�re
# 5      NaN  1896-01-01  Auguste Lumi�re, Louis Lumi�re
# 6      NaN         NaN                   Louis Lumi�re

# %%
iloc = df.iloc[1:6,[1,4,5]]
iloc
# Out:
#                                     title runtime                     genre
# 1                        Blacksmith Scene   1 min                     Short
# 2                          Pauvre Pierrot   4 min  Animation, Comedy, Short
# 3  Edison Kinetoscopic Record of a Sneeze   1 min        Documentary, Short
# 4   Employees Leaving the Lumi�re Factory   1 min        Documentary, Short
# 5                  The Arrival of a Train   1 min        Documentary, Short

# %%
df.iloc[:,[1,7]]
# Out:
#                                         title              director
# 0                                  Carmencita  William K.L. Dickson
# 1                            Blacksmith Scene  William K.L. Dickson
# 2                              Pauvre Pierrot         �mile Reynaud
# 3      Edison Kinetoscopic Record of a Sneeze  William K.L. Dickson
# 4       Employees Leaving the Lumi�re Factory         Louis Lumi�re
# ...                                       ...                   ...
# 46009                       The New Classmate   Ashwiny Iyer Tiwari
# 46010      Untitled Christopher Nolan Project     Christopher Nolan
# 46011                  Die Turnschuh-Giganten      Oliver Dommenget
# 46012                The Monster of Mangatiti                   NaN
# 46013                           The Last Word       Mark Pellington
#
# [46014 rows x 2 columns]

# %%
df.loc[:,['title','director']]
# Out:
#                                         title              director
# 0                                  Carmencita  William K.L. Dickson
# 1                            Blacksmith Scene  William K.L. Dickson
# 2                              Pauvre Pierrot         �mile Reynaud
# 3      Edison Kinetoscopic Record of a Sneeze  William K.L. Dickson
# 4       Employees Leaving the Lumi�re Factory         Louis Lumi�re
# ...                                       ...                   ...
# 46009                       The New Classmate   Ashwiny Iyer Tiwari
# 46010      Untitled Christopher Nolan Project     Christopher Nolan
# 46011                  Die Turnschuh-Giganten      Oliver Dommenget
# 46012                The Monster of Mangatiti                   NaN
# 46013                           The Last Word       Mark Pellington
#
# [46014 rows x 2 columns]

# %%
disjoint = df.iloc[[0,5],[3,8]]
disjoint
# Out:
#       rating writer
# 0  NOT RATED    NaN
# 5        NaN    NaN

# %%
df.iloc[3,5]
# Out:
# 'Documentary, Short'

# %%
df.iloc[100:80:-2,4]
# Out:
# 100    199 min
# 98      13 min
# 96      18 min
# 94      27 min
# 92      65 min
# 90      16 min
# 88      84 min
# 86      70 min
# 84      52 min
# 82      29 min
# Name: runtime, dtype: object

# %%
df.iloc[:10]
# Out:
#    imdbID                                   title  year     rating runtime  \
# 0       1                              Carmencita  1894  NOT RATED   1 min
# 1       5                        Blacksmith Scene  1893    UNRATED   1 min
# 2       3                          Pauvre Pierrot  1892        NaN   4 min
# 3       8  Edison Kinetoscopic Record of a Sneeze  1894        NaN   1 min
# 4      10   Employees Leaving the Lumi�re Factory  1895        NaN   1 min
# 5      12                  The Arrival of a Train  1896        NaN   1 min
# 6      14           Tables Turned on the Gardener  1895        NaN   1 min
# 7      29                           Baby's Dinner  1895        NaN   1 min
# 8      23                                 The Sea  1895        NaN   1 min
# 9      70                     D�molition d'un mur  1896        NaN   1 min
#
#                       genre    released                        director  \
# ...

# %%
df.iloc[:10,:2]
# Out:
#    imdbID                                   title
# 0       1                              Carmencita
# 1       5                        Blacksmith Scene
# 2       3                          Pauvre Pierrot
# 3       8  Edison Kinetoscopic Record of a Sneeze
# 4      10   Employees Leaving the Lumi�re Factory
# 5      12                  The Arrival of a Train
# 6      14           Tables Turned on the Gardener
# 7      29                           Baby's Dinner
# 8      23                                 The Sea
# 9      70                     D�molition d'un mur

# %%
x = df.columns.get_loc('director')
y = df.columns.get_loc('imdbID')
print(x)
print(y)
# Out:
# 7
# 0

# %%
df.iloc[:5,y:x]
# Out:
#    imdbID                                   title  year     rating runtime  \
# 0       1                              Carmencita  1894  NOT RATED   1 min
# 1       5                        Blacksmith Scene  1893    UNRATED   1 min
# 2       3                          Pauvre Pierrot  1892        NaN   4 min
# 3       8  Edison Kinetoscopic Record of a Sneeze  1894        NaN   1 min
# 4      10   Employees Leaving the Lumi�re Factory  1895        NaN   1 min
#
#                       genre    released
# 0        Documentary, Short         NaN
# 1                     Short  1893-05-09
# 2  Animation, Comedy, Short  1892-10-28
# 3        Documentary, Short  1894-01-09
# 4        Documentary, Short  1895-03-22

# %%
x = df.index[10]
y = df.index[15]
x
y
# Out:
# 15

# %%
s = df['imdbID']
x = df[10:30:4]
x
# Out:
#     imdbID                   title  year rating runtime           genre  \
# 10      91  The House of the Devil  1896    NaN   3 min   Short, Horror
# 14     138       The Bewitched Inn  1897    NaN   2 min   Short, Comedy
# 18     242   The Sign of the Cross  1899    NaN   3 min  Short, Fantasy
# 22     359   The India Rubber Head  1901    NaN   3 min   Short, Comedy
# 26     420     Alice in Wonderland  1903    NaN   8 min  Fantasy, Short
#
#       released                       director  \
# 10         NaN                 Georges M�li�s
# 14         NaN                 Georges M�li�s
# 18   6/30/1900                 Georges M�li�s
# 22         NaN                 Georges M�li�s
# 26  10/17/1903  Cecil M. Hepworth, Percy Stow
#
#                                       writer  \
# 10                            Georges M�li�s
# 14                            Georges M�li�s
# 18                            Georges M�li�s
# 22                                       NaN
# ...

# %%
start = 24
stop = 1000
x = df.loc[start:stop:170]
x
# Out:
#      imdbID                                           title  year     rating  \
# 24      399                          Jack and the Beanstalk  1902        NaN
# 194    9968  Broken Blossoms or The Yellow Man and the Girl  1919  NOT RATED
# 364   15648                             Battleship Potemkin  1925    UNRATED
# 534   19403                               Salt for Svanetia  1930      TV-14
# 704   21542                                  Westfront 1918  1930      TV-PG
# 874   23181                          The Man Who Played God  1932   APPROVED
#
#     runtime                genre    released  \
# 24   10 min       Short, Fantasy   7/15/1902
# 194  90 min       Drama, Romance  10/20/1919
# 364  66 min         History, War  12/24/1925
# 534  55 min          Documentary   5/24/1930
# 704  75 min  Drama, Romance, War   5/23/1930
# 874  80 min       Drama, Romance   2/19/1932
#
#                                director  \
# 24   George S. Fleming, Edwin S. Porter
# ...

# %%
df.sort_index()
# Out:
#         imdbID                                   title  year     rating  \
# 0            1                              Carmencita  1894  NOT RATED
# 1            5                        Blacksmith Scene  1893    UNRATED
# 2            3                          Pauvre Pierrot  1892        NaN
# 3            8  Edison Kinetoscopic Record of a Sneeze  1894        NaN
# 4           10   Employees Leaving the Lumi�re Factory  1895        NaN
# ...        ...                                     ...   ...        ...
# 46009  5005684                       The New Classmate  2015        NaN
# 46010  5013056      Untitled Christopher Nolan Project  2017        NaN
# 46011  5013980                  Die Turnschuh-Giganten  2016        NaN
# 46012  5016760                The Monster of Mangatiti  2015        NaN
# 46013  5023260                           The Last Word  2016        NaN
#
#       runtime                     genre    released              director  \
# ...

# %%
df.set_index('imdbID',inplace = True)

# %%
df
# Out:
#                                           title  year     rating runtime  \
# imdbID
# 1                                    Carmencita  1894  NOT RATED   1 min
# 5                              Blacksmith Scene  1893    UNRATED   1 min
# 3                                Pauvre Pierrot  1892        NaN   4 min
# 8        Edison Kinetoscopic Record of a Sneeze  1894        NaN   1 min
# 10        Employees Leaving the Lumi�re Factory  1895        NaN   1 min
# ...                                         ...   ...        ...     ...
# 5005684                       The New Classmate  2015        NaN     NaN
# 5013056      Untitled Christopher Nolan Project  2017        NaN     NaN
# 5013980                  Die Turnschuh-Giganten  2016        NaN     NaN
# 5016760                The Monster of Mangatiti  2015        NaN     NaN
# 5023260                           The Last Word  2016        NaN     NaN
#
#                             genre    released              director  \
# imdbID
# ...

# %%
df.sort_index()
# Out:
#                                           title  year     rating runtime  \
# imdbID
# 1                                    Carmencita  1894  NOT RATED   1 min
# 1                                    Carmencita  1894  NOT RATED   1 min
# 3                                Pauvre Pierrot  1892        NaN   4 min
# 5                              Blacksmith Scene  1893    UNRATED   1 min
# 8        Edison Kinetoscopic Record of a Sneeze  1894        NaN   1 min
# ...                                         ...   ...        ...     ...
# 5005684                       The New Classmate  2015        NaN     NaN
# 5013056      Untitled Christopher Nolan Project  2017        NaN     NaN
# 5013980                  Die Turnschuh-Giganten  2016        NaN     NaN
# 5016760                The Monster of Mangatiti  2015        NaN     NaN
# 5023260                           The Last Word  2016        NaN     NaN
#
#                             genre    released              director  \
# imdbID
# ...

# %%
display(df.head(10))
# Out:
#                                          title  year     rating runtime  \
# imdbID
# 1                                   Carmencita  1894  NOT RATED   1 min
# 5                             Blacksmith Scene  1893    UNRATED   1 min
# 3                               Pauvre Pierrot  1892        NaN   4 min
# 8       Edison Kinetoscopic Record of a Sneeze  1894        NaN   1 min
# 10       Employees Leaving the Lumi�re Factory  1895        NaN   1 min
# 12                      The Arrival of a Train  1896        NaN   1 min
# 14               Tables Turned on the Gardener  1895        NaN   1 min
# 29                               Baby's Dinner  1895        NaN   1 min
# 23                                     The Sea  1895        NaN   1 min
# 70                         D�molition d'un mur  1896        NaN   1 min
#
#                            genre    released                        director  \
# imdbID
# 1             Documentary, Short         NaN            William K.L. Dickson
# ...

# %%
df.set_index('genre',inplace = True)

# %%
df
# Out:
#                                                            title  year  \
# genre
# Documentary, Short                                    Carmencita  1894
# Short                                           Blacksmith Scene  1893
# Animation, Comedy, Short                          Pauvre Pierrot  1892
# Documentary, Short        Edison Kinetoscopic Record of a Sneeze  1894
# Documentary, Short         Employees Leaving the Lumi�re Factory  1895
# ...                                                          ...   ...
# Drama, Family                                  The New Classmate  2015
# Sci-Fi                        Untitled Christopher Nolan Project  2017
# Biography, Drama, War                     Die Turnschuh-Giganten  2016
# NaN                                     The Monster of Mangatiti  2015
# Comedy                                             The Last Word  2016
#
#                              rating runtime    released              director  \
# genre
# ...

# %%
df.columns
# Out:
# Index(['title', 'year', 'rating', 'runtime', 'released', 'director', 'writer',
#        'cast', 'metacritic', 'imdbRating', 'imdbVotes', 'poster', 'plot',
#        'fullplot', 'language', 'country', 'awards', 'lastupdated', 'type'],
#       dtype='object')

# %%
df.set_index('country',inplace = True)

# %%
df.sort_index()
# Out:
#                                                                title  year  \
# country
# Afghanistan                                           Frame by Frame  2015
# Afghanistan, France                      Wajma, an Afghan Love Story  2013
# Afghanistan, France, Germany, UK                  The Patience Stone  2012
# Afghanistan, Ireland, Japan                                    Osama  2003
# Afghanistan, USA                                   The Hornet's Nest  2014
# ...                                                              ...   ...
# NaN                                             Lead with Your Heart  2015
# NaN                                                          Tschick  2016
# NaN                               The Lion Guard: Return of the Roar  2015
# NaN                                         Barbie in Rock 'N Royals  2015
# NaN                                                        Priceless  2016
#
# ...

# %%
x = df.set_index('language')
x
# Out:
#                                            title  year     rating runtime  \
# language
# NaN                                   Carmencita  1894  NOT RATED   1 min
# NaN                             Blacksmith Scene  1893    UNRATED   1 min
# NaN                               Pauvre Pierrot  1892        NaN   4 min
# NaN       Edison Kinetoscopic Record of a Sneeze  1894        NaN   1 min
# NaN        Employees Leaving the Lumi�re Factory  1895        NaN   1 min
# ...                                          ...   ...        ...     ...
# Hindi                          The New Classmate  2015        NaN     NaN
# English       Untitled Christopher Nolan Project  2017        NaN     NaN
# German                    Die Turnschuh-Giganten  2016        NaN     NaN
# English                 The Monster of Mangatiti  2015        NaN     NaN
# English                            The Last Word  2016        NaN     NaN
#
#             released              director  \
# language
# ...

# %%
x.sort_index()
# Out:
#                                                                              title  \
# language
# Aboriginal, English                                             Rabbit-Proof Fence
# Aboriginal, English                                 When Dinosaurs Ruled the Earth
# Aboriginal, English                                                     Ten Canoes
# Aboriginal, English, French, Portuguese                            The Interpreter
# Aboriginal, Japanese, Hokkien                 Warriors of the Rainbow: Seediq Bale
# ...                                                                            ...
# NaN                                                       Barbie in Rock 'N Royals
# NaN                                                                       Prologue
# NaN                                                                  Very Big Shot
# NaN                                      Middle School: The Worst Years of My Life
# ...

# %%
df.set_index('type',inplace = True)

# %%
df.head(200)
# Out:
#                                         title  year     rating runtime  \
# type
# movie                              Carmencita  1894  NOT RATED   1 min
# movie                        Blacksmith Scene  1893    UNRATED   1 min
# movie                          Pauvre Pierrot  1892        NaN   4 min
# movie  Edison Kinetoscopic Record of a Sneeze  1894        NaN   1 min
# movie   Employees Leaving the Lumi�re Factory  1895        NaN   1 min
# ...                                       ...   ...        ...     ...
# movie                              The Busher  1919  Not Rated  55 min
# movie                         Daddy-Long-Legs  1919    UNRATED  85 min
# movie                        A Day's Pleasure  1919       TV-G  24 min
# movie              The Delicious Little Devil  1919       TV-G  63 min
# movie               Don't Change Your Husband  1919        NaN  71 min
#
#          released              director  \
# type
# movie         NaN  William K.L. Dickson
# ...

# %%
df1 = pd.read_csv(r'E:\4TH SEMESTER DATA\DATA ANALYSIS\hr_data.csv')
df1
# Out:
#      EmployeeID  Age  Gender Department        JobRole  Education  \
# 0             1   56    Male      Sales        Manager          3
# 1             2   46    Male      Sales        Manager          1
# 2             3   32  Female    Finance       Engineer          1
# 3             4   25  Female      Sales  HR Specialist          1
# 4             5   38    Male         HR  HR Specialist          2
# ..          ...  ...     ...        ...            ...        ...
# 995         996   41  Female      Sales       Engineer          1
# 996         997   32    Male    Finance  HR Specialist          4
# 997         998   46  Female      Sales       Engineer          3
# 998         999   25    Male    Finance  HR Specialist          3
# 999        1000   22  Female      Sales       Engineer          2
#
#     MaritalStatus  MonthlyIncome OverTime  YearsAtCompany  \
# 0         Married          16330      Yes               9
# ...

# %%
df1.set_index('Department',inplace = True)

# %%
x = df1.sort_index()

# %%
y  = x.loc['D':'T']
y
# Out:
#              EmployeeID  Age  Gender          JobRole  Education  \
# Department
# Development         799   19  Female          Manager          5
# Development         592   42  Female         Engineer          1
# Development         433   27    Male         Engineer          3
# Development         589   20  Female    HR Specialist          2
# Development         161   30    Male          Manager          2
# ...                 ...  ...     ...              ...        ...
# Sales               498   41    Male    HR Specialist          4
# Sales               493   52    Male    HR Specialist          2
# Sales               492   52    Male  Sales Executive          4
# Sales               535   56    Male    HR Specialist          1
# Sales              1000   22  Female         Engineer          2
#
#             MaritalStatus  MonthlyIncome OverTime  YearsAtCompany  \
# Department
# Development      Divorced           5786       No              35
# ...

# %%
z = df1.sort_index(ascending = False)
z
# Out:
#              EmployeeID  Age  Gender        JobRole  Education MaritalStatus  \
# Department
# Sales                 1   56    Male        Manager          3       Married
# Sales               486   38  Female       Engineer          4       Married
# Sales               477   43  Female        Manager          1      Divorced
# Sales               476   27    Male        Manager          2       Married
# Sales               462   57  Female       Engineer          5        Single
# ...                 ...  ...     ...            ...        ...           ...
# Development         106   40  Female        Manager          4        Single
# Development         598   33  Female       Engineer          1       Married
# Development         108   54    Male  HR Specialist          5        Single
# Development         594   55    Male  HR Specialist          4      Divorced
# Development         607   58    Male  HR Specialist          2       Married
#
# ...

# %%
x.index.is_monotonic_decreasing
# Out:
# False

# %%
z.index.is_monotonic_decreasing
# Out:
# True

# %%
z.loc['S':'F']
# Out:
#             EmployeeID  Age  Gender          JobRole  Education MaritalStatus  \
# Department
# HR                 856   57  Female          Manager          1        Single
# HR                 705   47  Female    HR Specialist          3      Divorced
# HR                 693   49  Female  Sales Executive          4        Single
# HR                 685   38  Female         Engineer          2        Single
# HR                 134   21    Male    HR Specialist          5        Single
# ...                ...  ...     ...              ...        ...           ...
# Finance            920   26  Female         Engineer          5        Single
# Finance            491   41    Male    HR Specialist          5       Married
# Finance            132   56    Male  Sales Executive          5       Married
# Finance            500   49  Female    HR Specialist          5       Married
# Finance            499   40    Male    HR Specialist          5       Married
#
# ...

# %%
df1.rename(columns = {'Gender':'GENDER'})
# Out:
#             EmployeeID  Age  GENDER        JobRole  Education MaritalStatus  \
# Department
# Sales                1   56    Male        Manager          3       Married
# Sales                2   46    Male        Manager          1        Single
# Finance              3   32  Female       Engineer          1      Divorced
# Sales                4   25  Female  HR Specialist          1       Married
# HR                   5   38    Male  HR Specialist          2       Married
# ...                ...  ...     ...            ...        ...           ...
# Sales              996   41  Female       Engineer          1      Divorced
# Finance            997   32    Male  HR Specialist          4       Married
# Sales              998   46  Female       Engineer          3      Divorced
# Finance            999   25    Male  HR Specialist          3       Married
# Sales             1000   22  Female       Engineer          2      Divorced
#
# ...

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#     Department  EmployeeID  Age  Gender        JobRole  Education  \
# 0        Sales           1   56    Male        Manager          3
# 1        Sales           2   46    Male        Manager          1
# 2      Finance           3   32  Female       Engineer          1
# 3        Sales           4   25  Female  HR Specialist          1
# 4           HR           5   38    Male  HR Specialist          2
# ..         ...         ...  ...     ...            ...        ...
# 995      Sales         996   41  Female       Engineer          1
# 996    Finance         997   32    Male  HR Specialist          4
# 997      Sales         998   46  Female       Engineer          3
# 998    Finance         999   25    Male  HR Specialist          3
# 999      Sales        1000   22  Female       Engineer          2
#
#     MaritalStatus  MonthlyIncome OverTime  YearsAtCompany  \
# 0         Married          16330      Yes               9
# ...

# %%
df1.query('25<Age<50')
# Out:
#       Department  EmployeeID  Age  Gender        JobRole  Education  \
# 1          Sales           2   46    Male        Manager          1
# 2        Finance           3   32  Female       Engineer          1
# 4             HR           5   38    Male  HR Specialist          2
# 6    Development           7   36    Male        Manager          5
# 7        Finance           8   40    Male       Engineer          4
# ..           ...         ...  ...     ...            ...        ...
# 992           HR         993   30  Female  HR Specialist          1
# 993        Sales         994   48  Female        Manager          1
# 995        Sales         996   41  Female       Engineer          1
# 996      Finance         997   32    Male  HR Specialist          4
# 997        Sales         998   46  Female       Engineer          3
#
#     MaritalStatus  MonthlyIncome OverTime  YearsAtCompany  \
# 1          Single           6891      Yes              22
# ...

# %%
df.dtypes
# Out:
# title           object
# year            object
# rating          object
# runtime         object
# released        object
# director        object
# writer          object
# cast            object
# metacritic     float64
# imdbRating     float64
# imdbVotes      float64
# poster          object
# plot            object
# fullplot        object
# language        object
# awards          object
# lastupdated     object
# dtype: object

# %%
df1['Age'].mean()
# Out:
# 38.745

# %%
df1['Age'].median()
# Out:
# 40.0

# %%
df1['Age'].mode()
# Out:
# 0    50
# Name: Age, dtype: int64

# %%
df1['Age'].value_counts().sum()
# Out:
# 1000

# %%
df1['Age'].sort_values()
# Out:
# 904    18
# 787    18
# 771    18
# 563    18
# 587    18
#        ..
# 767    59
# 344    59
# 335    59
# 56     59
# 535    59
# Name: Age, Length: 1000, dtype: int64

# %%
df1['Age'].unique()
# Out:
# array([56, 46, 32, 25, 38, 36, 40, 28, 41, 53, 57, 20, 39, 19, 47, 55, 50,
#        29, 42, 44, 59, 45, 33, 54, 24, 26, 35, 21, 31, 43, 37, 52, 34, 23,
#        51, 27, 48, 58, 18, 22, 30, 49], dtype=int64)

# %%
df1['Age'].nunique()
# Out:
# 42

# %%
df.dtypes
# Out:
# title           object
# year            object
# rating          object
# runtime         object
# released        object
# director        object
# writer          object
# cast            object
# metacritic     float64
# imdbRating     float64
# imdbVotes      float64
# poster          object
# plot            object
# fullplot        object
# language        object
# awards          object
# lastupdated     object
# dtype: object

# %%
df['year'] = pd.to_numeric(df['year'], errors='coerce')
df = df.dropna(subset=['year'])
df['year'] = df['year'].astype('int64')

# %%
df.dtypes
# Out:
# title           object
# year             int64
# rating          object
# runtime         object
# released        object
# director        object
# writer          object
# cast            object
# metacritic     float64
# imdbRating     float64
# imdbVotes      float64
# poster          object
# plot            object
# fullplot        object
# language        object
# awards          object
# lastupdated     object
# dtype: object

# %%
df1.dtypes
# Out:
# Department              object
# EmployeeID               int64
# Age                      int64
# Gender                  object
# JobRole                 object
# Education                int64
# MaritalStatus           object
# MonthlyIncome            int64
# OverTime                object
# YearsAtCompany           int64
# YearsWithCurrManager     int64
# PerformanceRating        int64
# PromotionStatus         object
# dtype: object

# %%
df1
# Out:
#     Department  EmployeeID  Age  Gender        JobRole  Education  \
# 0        Sales           1   56    Male        Manager          3
# 1        Sales           2   46    Male        Manager          1
# 2      Finance           3   32  Female       Engineer          1
# 3        Sales           4   25  Female  HR Specialist          1
# 4           HR           5   38    Male  HR Specialist          2
# ..         ...         ...  ...     ...            ...        ...
# 995      Sales         996   41  Female       Engineer          1
# 996    Finance         997   32    Male  HR Specialist          4
# 997      Sales         998   46  Female       Engineer          3
# 998    Finance         999   25    Male  HR Specialist          3
# 999      Sales        1000   22  Female       Engineer          2
#
#     MaritalStatus  MonthlyIncome OverTime  YearsAtCompany  \
# 0         Married          16330      Yes               9
# ...

# %%
df
# Out:
#                                         title  year     rating runtime  \
# type
# movie                              Carmencita   102  NOT RATED   1 min
# movie                        Blacksmith Scene   101    UNRATED   1 min
# movie                          Pauvre Pierrot   100        NaN   4 min
# movie  Edison Kinetoscopic Record of a Sneeze   102        NaN   1 min
# movie   Employees Leaving the Lumi�re Factory   103        NaN   1 min
# ...                                       ...   ...        ...     ...
# movie                       The New Classmate   -33        NaN     NaN
# movie      Untitled Christopher Nolan Project   -31        NaN     NaN
# movie                  Die Turnschuh-Giganten   -32        NaN     NaN
# movie                The Monster of Mangatiti   -33        NaN     NaN
# movie                           The Last Word   -32        NaN     NaN
#
#          released              director  \
# type
# movie         NaN  William K.L. Dickson
# ...

# %%
df['imdbVotes'] = pd.to_numeric(df['imdbVotes'],errors = 'coerce')
df = df.dropna(subset=['imdbVotes'])

# %%
df['imdbVotes'] = df['imdbVotes'].astype('int64')

# %%
df.dtypes
# Out:
# title           object
# year             int64
# rating          object
# runtime         object
# released        object
# director        object
# writer          object
# cast            object
# metacritic     float64
# imdbRating     float64
# imdbVotes        int64
# poster          object
# plot            object
# fullplot        object
# language        object
# awards          object
# lastupdated     object
# dtype: object

# %%
df.columns
# Out:
# Index(['title', 'year', 'rating', 'runtime', 'released', 'director', 'writer',
#        'cast', 'metacritic', 'imdbRating', 'imdbVotes', 'poster', 'plot',
#        'fullplot', 'language', 'awards', 'lastupdated'],
#       dtype='object')

# %%
df.drop(columns = 'released')
# Out:
#                                                    title  year     rating  \
# type
# movie                                         Carmencita   102  NOT RATED
# movie                                   Blacksmith Scene   101    UNRATED
# movie                                     Pauvre Pierrot   100        NaN
# movie             Edison Kinetoscopic Record of a Sneeze   102        NaN
# movie              Employees Leaving the Lumi�re Factory   103        NaN
# ...                                                  ...   ...        ...
# movie  LEGO DC Super Heroes: Justice League - Attack ...   -33        NaN
# movie                                  Cosmos Laundromat   -33        NaN
# movie                                          Our Times   -33        NaN
# movie                                       Thani Oruvan   -33        NaN
# movie                                 Bana Masal Anlatma   -33        NaN
#
#        runtime              director  \
# type
# ...

# %%
x = df.select_dtypes(include = ['object'])

# %%
x
# Out:
#                                                    title     rating  runtime  \
# type
# movie                                         Carmencita  NOT RATED    1 min
# movie                                   Blacksmith Scene    UNRATED    1 min
# movie                                     Pauvre Pierrot        NaN    4 min
# movie             Edison Kinetoscopic Record of a Sneeze        NaN    1 min
# movie              Employees Leaving the Lumi�re Factory        NaN    1 min
# ...                                                  ...        ...      ...
# movie  LEGO DC Super Heroes: Justice League - Attack ...        NaN   77 min
# movie                                  Cosmos Laundromat        NaN   12 min
# movie                                          Our Times        NaN      NaN
# movie                                       Thani Oruvan        NaN  160 min
# movie                                 Bana Masal Anlatma        NaN  103 min
#
# ...

# %%
df1.isnull().sum()
# Out:
# Department              0
# EmployeeID              0
# Age                     0
# Gender                  0
# JobRole                 0
# Education               0
# MaritalStatus           0
# MonthlyIncome           0
# OverTime                0
# YearsAtCompany          0
# YearsWithCurrManager    0
# PerformanceRating       0
# PromotionStatus         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# title              0
# year               0
# rating         19693
# runtime         1404
# released        2003
# director         458
# writer          2787
# cast             854
# metacritic     34830
# imdbRating         0
# imdbVotes          0
# poster          8804
# plot            3239
# fullplot        3920
# language         827
# awards         20786
# lastupdated        0
# dtype: int64

# %%
df.fillna(0,inplace = True)

# %%
data = {'Stock':['books','chairs','table','this','that'],
        'Price': [120,30,133,200,399]
       }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Stock  Price
# 0   books    120
# 1  chairs     30
# 2   table    133
# 3    this    200
# 4    that    399

# %%
x = df['Price']> 100
x
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Price, dtype: bool

# %%
per = x.mean()*100
per
# Out:
# 80.0

# %%
x = df[(df['Price']>100) & (df['Price']<300)]
x
# Out:
#    Stock  Price
# 0  books    120
# 2  table    133
# 3   this    200

# %%
x = df[(df['Price']<100) | (df['Price']>200)]
x
# Out:
#     Stock  Price
# 1  chairs     30
# 4    that    399

# %%
high_price = df[df['Price']>300]
high_price
# Out:
#   Stock  Price
# 4  that    399

# %%
mid_price = df[(df['Price']>150) & (df['Price']<300)]
mid_price
# Out:
#   Stock  Price
# 3  this    200

# %%
df.loc[df['Price']>300]
# Out:
#   Stock  Price
# 4  that    399

# %%
df.iloc[(df['Price']>150).values]
# Out:
#   Stock  Price
# 3  this    200
# 4  that    399

# %%
sorted = df.set_index('Stock').sort_index()
sorted
# Out:
#         Price
# Stock
# books     120
# chairs     30
# table     133
# that      399
# this      200

# %%
sorted.loc['that']
# Out:
# Price    399
# Name: that, dtype: int64

# %%
df['Price'].mean()
# Out:
# 176.4

# %%
df.query('100<Price<300')
# Out:
#    Stock  Price
# 0  books    120
# 2  table    133
# 3   this    200

# %%
df['Price'].where(df['Price']>200,inplace = False)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4    399.0
# Name: Price, dtype: float64

# %%
df.mask(df['Price']<150)
# Out:
#   Stock  Price
# 0   NaN    NaN
# 1   NaN    NaN
# 2   NaN    NaN
# 3  this  200.0
# 4  that  399.0

# %%
df
# Out:
#     Stock  Price
# 0   books    120
# 1  chairs     30
# 2   table    133
# 3    this    200
# 4    that    399

# %%
df.iloc[:3]
# Out:
#     Stock  Price
# 0   books    120
# 1  chairs     30
# 2   table    133

# %%
df.loc[df['Stock']=='chairs']
# Out:
#     Stock  Price
# 1  chairs     30

# %%
df1 = pd.DataFrame({'A':[1,2],'B':['X','Y']})
df2 = pd.DataFrame({'C':['a','b'],'D':[3,4]})

# %%
x = pd.merge(df1,df2,how = 'cross')
x
# Out:
#    A  B  C  D
# 0  1  X  a  3
# 1  1  X  b  4
# 2  2  Y  a  3
# 3  2  Y  b  4

# %%
df1 = pd.DataFrame({'A':[1,2],'B':['X','Y']})
df2 = pd.DataFrame({'C':['a','b'],'D':[3,4]})

# %%
df1['Key'] = 1
df2['Key'] = 1

# %%
x = pd.concat([df1,df2])
x
# Out:
#      A    B    C    D
# 0  1.0    X  NaN  NaN
# 1  2.0    Y  NaN  NaN
# 0  NaN  NaN    a  3.0
# 1  NaN  NaN    b  4.0

# %%
cartesian = pd.merge(df1,df2,on = 'Key').drop('Key',axis = 1)

# %%
cartesian
# Out:
#    A  B  C  D
# 0  1  X  a  3
# 1  1  X  b  4
# 2  2  Y  a  3
# 3  2  Y  b  4

# %%
df = pd.read_csv(r'E:\4TH SEMESTER DATA\DATA ANALYSIS\ALL MATERIAL\Copy of pakistan_education_data(1).csv')

# %%
df.columns
# Out:
# Index(['StudentID', 'Name', 'University', 'City', 'Program', 'Level', 'Year',
#        'GPA', 'Status', 'Age', 'Discipline', 'FundingType', 'Scholarship',
#        'Hostel', 'Extracurricular'],
#       dtype='object')

# %%
df.set_index('StudentID',inplace = True)

# %%
df
# Out:
#                       Name                                      University  \
# StudentID
# 1987             Omar Rana        Lahore University of Management Sciences
# 8391           Zara Sheikh                       University of Balochistan
# 4976            Zara Saeed                          University of Peshawar
# 1598           Fatima Khan                         Quaid-i-Azam University
# 6836           Ahmed Malik     COMSATS Institute of Information Technology
# ...                    ...                                             ...
# 5697       Fatima Chaudhry     COMSATS Institute of Information Technology
# 1082        Aisha Chaudhry  National University of Sciences and Technology
# 4817          Ahmed Ansari                          University of Peshawar
# 9710            Aisha Khan                         Quaid-i-Azam University
# 8151            Amina Butt                              Karachi University
#
# ...

# %%
df1
# Out:
#    A  B
# 0  1  X
# 1  2  Y

# %%
data = {'A':[233,344,555],'B':[345,245,224],'C':[344,234,987]}

# %%
df = pd.DataFrame(data)

# %%
df.style.highlight_max(color = 'blue',axis = 1)
# Out:
# <style type="text/css">
# #T_eb5fd_row0_col1, #T_eb5fd_row1_col0, #T_eb5fd_row2_col2 {
#   background-color: blue;
# }
# </style>
# <table id="T_eb5fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb5fd_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_eb5fd_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_eb5fd_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb5fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb5fd_row0_col0" class="data row0 col0" >233</td>
#       <td id="T_eb5fd_row0_col1" class="data row0 col1" >345</td>
#       <td id="T_eb5fd_row0_col2" class="data row0 col2" >344</td>
#     </tr>
#     <tr>
#       <th id="T_eb5fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb5fd_row1_col0" class="data row1 col0" >344</td>
# ...

# %%
df.style.highlight_min(color = 'grey',axis = 0)
# Out:
# <style type="text/css">
# #T_4f669_row0_col0, #T_4f669_row1_col2, #T_4f669_row2_col1 {
#   background-color: grey;
# }
# </style>
# <table id="T_4f669">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f669_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_4f669_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_4f669_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f669_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f669_row0_col0" class="data row0 col0" >233</td>
#       <td id="T_4f669_row0_col1" class="data row0 col1" >345</td>
#       <td id="T_4f669_row0_col2" class="data row0 col2" >344</td>
#     </tr>
#     <tr>
#       <th id="T_4f669_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f669_row1_col0" class="data row1 col0" >344</td>
# ...

# %%
x = df.loc[df['C'].idxmax()]
x
# Out:
# A    555
# B    224
# C    987
# Name: 2, dtype: int64

# %%
matrix = [(10,56,17),
          (np.NAN,23,45),
          (48,np.NAN,89)]
df = pd.DataFrame(matrix,index= list('abc'),columns = list('xyz'))

# %%
df
# Out:
#       x     y   z
# a  10.0  56.0  17
# b   NaN  23.0  45
# c  48.0   NaN  89

# %%
df['x'].max()
# Out:
# 48.0

# %%
df[['x','y']].max()
# Out:
# x    48.0
# y    56.0
# dtype: float64

# %%
df.max(axis = 1)
# Out:
# a    56.0
# b    45.0
# c    89.0
# dtype: float64

# %%
df.max(axis = 0)
# Out:
# x    48.0
# y    56.0
# z    89.0
# dtype: float64

# %%
s = pd.Series([1,2,4,5,6,2,4,2])

# %%
counts = s.value_counts()

# %%
counts.index[0]
# Out:
# 2

# %%
s.mode()[0]
# Out:
# 2

# %%
matrix = [(10,56,17),
          (np.NAN,[23,56,87],45),
          (48,np.NAN,[89,67,78])]
df = pd.DataFrame(matrix,index= list('abc'),columns = list('xyz'))

# %%
df
# Out:
#       x             y             z
# a  10.0            56            17
# b   NaN  [23, 56, 87]            45
# c  48.0           NaN  [89, 67, 78]

# %%
df.explode('y')
# Out:
#       x    y             z
# a  10.0   56            17
# b   NaN   23            45
# b   NaN   56            45
# b   NaN   87            45
# c  48.0  NaN  [89, 67, 78]
