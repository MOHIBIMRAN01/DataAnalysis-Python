# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\pc\Desktop\movies_initial - movies_initial.csv")

# %%
df.head(2)
# Out:
#    imdbID             title  year     rating runtime               genre  \
# 0       1        Carmencita  1894  NOT RATED   1 min  Documentary, Short
# 1       5  Blacksmith Scene  1893    UNRATED   1 min               Short
#
#      released              director writer                      cast  ...  \
# 0         NaN  William K.L. Dickson    NaN                Carmencita  ...
# 1  1893-05-09  William K.L. Dickson    NaN  Charles Kayser, John Ott  ...
#
#    imdbRating  imdbVotes                                             poster  \
# 0         5.9     1032.0  https://m.media-amazon.com/images/M/MV5BMjAzND...
# 1         6.2     1189.0                                                NaN
#
#                                                 plot  \
# 0  Performing on what looks like a small wooden s...
# 1  Three men hammer on an anvil and pass a bottle...
#
#                                             fullplot language country  awards  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46014 entries, 0 to 46013
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdbID       46014 non-null  int64
#  1   title        46014 non-null  object
#  2   year         45938 non-null  float64
#  3   rating       24629 non-null  object
#  4   runtime      0 non-null      float64
#  5   genre        45615 non-null  object
#  6   released     43002 non-null  object
#  7   director     45409 non-null  object
#  8   writer       42942 non-null  object
#  9   cast         44928 non-null  object
#  10  metacritic   9401 non-null   float64
#  11  imdbRating   46014 non-null  float64
#  12  imdbVotes    44299 non-null  float64
#  13  poster       35798 non-null  object
#  14  plot         42161 non-null  object
#  15  fullplot     41421 non-null  object
#  16  language     44899 non-null  object
#  17  country      45830 non-null  object
# ...

# %%
df.shape
# Out:
# (46014, 21)

# %%
df['runtime'] = pd.to_numeric(df['runtime'],errors = 'coerce')

# %%
df.dtypes
# Out:
# imdbID           int64
# title           object
# year            object
# rating          object
# runtime        float64
# genre           object
# released        object
# director        object
# writer          object
# cast            object
# metacritic     float64
# imdbRating     float64
# imdbVotes      float64
# poster          object
# plot            object
# fullplot        object
# language        object
# country         object
# awards          object
# lastupdated     object
# type            object
# dtype: object

# %%
lng_movies = df['runtime']>1
lng_movies
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46009    False
# 46010    False
# 46011    False
# 46012    False
# 46013    False
# Name: runtime, Length: 46014, dtype: bool

# %%
high_rating = df['imdbRating']>8
high_rating
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46009    False
# 46010    False
# 46011    False
# 46012    False
# 46013    False
# Name: imdbRating, Length: 46014, dtype: bool

# %%
fil_movies = df.query('90<=runtime<=130')
fil_movies
# Out:
# Empty DataFrame
# Columns: [imdbID, title, year, rating, runtime, genre, released, director, writer, cast, metacritic, imdbRating, imdbVotes, poster, plot, fullplot, language, country, awards, lastupdated, type]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['imdbRating'] = df['imdbRating'].where(df['imdbRating']<=9,9)

# %%
df['imdbRating']
# Out:
# 0        5.9
# 1        6.2
# 2        6.7
# 3        5.9
# 4        6.9
#         ...
# 46009    9.0
# 46010    9.0
# 46011    9.0
# 46012    9.0
# 46013    9.0
# Name: imdbRating, Length: 46014, dtype: float64

# %%
masked_movies = df.mask(df['year']>2010)
masked_movies
masked_movies_cleaned = masked_movies.dropna(how = 'all')
masked_movies_cleaned
# Out:
#           imdbID                                   title    year     rating  \
# 0            1.0                              Carmencita  1894.0  NOT RATED
# 1            5.0                        Blacksmith Scene  1893.0    UNRATED
# 2            3.0                          Pauvre Pierrot  1892.0        NaN
# 3            8.0  Edison Kinetoscopic Record of a Sneeze  1894.0        NaN
# 4           10.0   Employees Leaving the Lumi�re Factory  1895.0        NaN
# ...          ...                                     ...     ...        ...
# 45265  4354616.0            Untitled Woody Allen Project     NaN        NaN
# 45549  4584528.0                         A Dancer's Life  1972.0        NaN
# 45613  4635282.0                                  The OA     NaN        NaN
# 45875  4876302.0                 Collective: Unconscious     NaN        NaN
# 45888   475380.0               Scenes of a Sexual Nature  2006.0          R
#
# ...

# %%
df['year'] = pd.to_numeric(df['year'],errors = 'coerce')

# %%
x = df['imdbRating'].between(7,9)
x
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46009     True
# 46010     True
# 46011     True
# 46012     True
# 46013     True
# Name: imdbRating, Length: 46014, dtype: bool

# %%
y = df['year'].between(2000,2010)
y
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46009    False
# 46010    False
# 46011    False
# 46012    False
# 46013    False
# Name: year, Length: 46014, dtype: bool

# %%
final_criteria = x & y
final_criteria
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46009    False
# 46010    False
# 46011    False
# 46012    False
# 46013    False
# Length: 46014, dtype: bool

# %%
filter_movies_sql = df[final_criteria ]

filter_movies_sql
# Out:
#         imdbID                                  title    year     rating  \
# 18116   118694                   In the Mood for Love  2000.0         PG
# 18172   118852                         Chinese Coffee  2000.0          R
# 18203   118926                    The Dancer Upstairs  2002.0          R
# 18598   120263            Songs from the Second Floor  2000.0  NOT RATED
# 18651   120454                                  Vinyl  2000.0        NaN
# ...        ...                                    ...     ...        ...
# 43919  3610936                                  Gaiir  2009.0        NaN
# 44006  3645848          Crossfire: Hate Is Like a Gun  2005.0        NaN
# 44326  3783464                    Be dune saade chaar  2009.0        NaN
# 44609  3948786                           Memory Vague  2009.0        NaN
# 44763  4047734  Coelacanth: The Fish That Time Forgot  2001.0        NaN
#
#        runtime                   genre   released          director  \
# ...

# %%
z = df['rating'].between('PG','PG-13')

# %%
z
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46009    False
# 46010    False
# 46011    False
# 46012    False
# 46013    False
# Name: rating, Length: 46014, dtype: bool

# %%
final_criteria = x & y & z
final_criteria
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46009    False
# 46010    False
# 46011    False
# 46012    False
# 46013    False
# Length: 46014, dtype: bool

# %%
df[final_criteria]
# Out:
#         imdbID                                              title    year  \
# 18116   118694                               In the Mood for Love  2000.0
# 18805   120737  The Lord of the Rings: The Fellowship of the Ring  2001.0
# 18852   120903                                              X-Men  2000.0
# 18870   121164                                       Corpse Bride  2005.0
# 18893   121766       Star Wars: Episode III - Revenge of the Sith  2005.0
# ...        ...                                                ...     ...
# 36675  1668200                                        Sarah's Key  2010.0
# 36709  1673430                        Superman/Batman: Apocalypse  2010.0
# 36888  1696202             DC Showcase Original Shorts Collection  2010.0
# 37056  1714832                                     Do Dooni Chaar  2010.0
# 37273  1740707                                        Trollhunter  2010.0
#
#       rating  runtime                         genre    released  \
# ...

# %%
final_criteria2 = x | y & z
final_criteria2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46009     True
# 46010     True
# 46011     True
# 46012     True
# 46013     True
# Length: 46014, dtype: bool

# %%
df[final_criteria2]
# Out:
#         imdbID                               title    year rating  runtime  \
# 5           12              The Arrival of a Train  1896.0    NaN      NaN
# 6           14       Tables Turned on the Gardener  1895.0    NaN      NaN
# 16         211                  A Trip to the Moon  1898.0    NaN      NaN
# 22         359               The India Rubber Head  1901.0    NaN      NaN
# 25         417                  A Trip to the Moon  1902.0   TV-G      NaN
# ...        ...                                 ...     ...    ...      ...
# 46009  5005684                   The New Classmate  2015.0    NaN      NaN
# 46010  5013056  Untitled Christopher Nolan Project  2017.0    NaN      NaN
# 46011  5013980              Die Turnschuh-Giganten  2016.0    NaN      NaN
# 46012  5016760            The Monster of Mangatiti  2015.0    NaN      NaN
# 46013  5023260                       The Last Word  2016.0    NaN      NaN
#
# ...

# %%
final_criteria3 = x | y | z
final_criteria3
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46009     True
# 46010     True
# 46011     True
# 46012     True
# 46013     True
# Length: 46014, dtype: bool

# %%
df[final_criteria3]
# Out:
#         imdbID                               title    year rating  runtime  \
# 5           12              The Arrival of a Train  1896.0    NaN      NaN
# 6           14       Tables Turned on the Gardener  1895.0    NaN      NaN
# 16         211                  A Trip to the Moon  1898.0    NaN      NaN
# 22         359               The India Rubber Head  1901.0    NaN      NaN
# 25         417                  A Trip to the Moon  1902.0   TV-G      NaN
# ...        ...                                 ...     ...    ...      ...
# 46009  5005684                   The New Classmate  2015.0    NaN      NaN
# 46010  5013056  Untitled Christopher Nolan Project  2017.0    NaN      NaN
# 46011  5013980              Die Turnschuh-Giganten  2016.0    NaN      NaN
# 46012  5016760            The Monster of Mangatiti  2015.0    NaN      NaN
# 46013  5023260                       The Last Word  2016.0    NaN      NaN
#
# ...

# %%
u = df['country'] == 'USA'	
u
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 46009    False
# 46010    False
# 46011    False
# 46012    False
# 46013     True
# Name: country, Length: 46014, dtype: bool

# %%
df[u]
# Out:
#         imdbID                                      title    year     rating  \
# 0            1                                 Carmencita  1894.0  NOT RATED
# 1            5                           Blacksmith Scene  1893.0    UNRATED
# 3            8     Edison Kinetoscopic Record of a Sneeze  1894.0        NaN
# 15         192                     Ella Lola, a la Trilby  1898.0        NaN
# 23         364             Panorama of Esplanade by Night  1901.0        NaN
# ...        ...                                        ...     ...        ...
# 45995  4981636  Middle School: The Worst Years of My Life  2016.0        NaN
# 46001  4991652                                     Camino  2016.0        NaN
# 46003  4991512                                     Tramps  2015.0        NaN
# 46006  4995590                                     Junjun  2015.0        NaN
# 46013  5023260                              The Last Word  2016.0        NaN
#
# ...

# %%
df['country']
# Out:
# 0                USA
# 1                USA
# 2             France
# 3                USA
# 4             France
#             ...
# 46009          India
# 46010        USA, UK
# 46011        Germany
# 46012    New Zealand
# 46013            USA
# Name: country, Length: 46014, dtype: object

# %%
df2 = pd.read_csv(r"C:\Users\pc\Desktop\pakistan_population_statistics_2017_20190603.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433 entries, 0 to 432
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   admin3Name_en  433 non-null    object
#  1   admin3Pcode    433 non-null    object
#  2   admin2Name_en  433 non-null    object
#  3   admin2Pcode    433 non-null    object
#  4   admin1Name_en  433 non-null    object
#  5   admin1Pcode    433 non-null    object
#  6   admin0Name_en  433 non-null    object
#  7   admin0Pcode    433 non-null    object
#  8   Total_pop      433 non-null    float64
# dtypes: float64(1), object(8)
# memory usage: 30.6+ KB

# %%
df2.shape
# Out:
# (433, 9)

# %%
df2.columns
# Out:
# Index(['admin3Name_en', 'admin3Pcode', 'admin2Name_en', 'admin2Pcode',
#        'admin1Name_en', 'admin1Pcode', 'admin0Name_en', 'admin0Pcode',
#        ' Total_pop '],
#       dtype='object')

# %%
population = df2[' Total_pop '] > 1000000
population
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 428    False
# 429    False
# 430    False
# 431    False
# 432    False
# Name:  Total_pop , Length: 433, dtype: bool

# %%
 df2[' Total_pop '] > 1000000
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 428    False
# 429    False
# 430    False
# 431    False
# 432    False
# Name:  Total_pop , Length: 433, dtype: bool

# %%
df2.dtypes
# Out:
# admin3Name_en     object
# admin3Pcode       object
# admin2Name_en     object
# admin2Pcode       object
# admin1Name_en     object
# admin1Pcode       object
# admin0Name_en     object
# admin0Pcode       object
#  Total_pop       float64
# dtype: object

# %%
df2.head()
# Out:
#    admin3Name_en admin3Pcode admin2Name_en admin2Pcode       admin1Name_en  \
# 0     Abbottabad     PK20101    Abbottabad       PK201  Khyber Pakhtunkhwa
# 1  Ahmadupr East     PK60305    Bahawalpur       PK603              Punjab
# 2  Ahmedpur Sial     PK61201         Jhang       PK612              Punjab
# 3           Alai     PK20301      Batagram       PK203  Khyber Pakhtunkhwa
# 4         Alipur     PK62301  Muzaffargarh       PK623              Punjab
#
#   admin1Pcode admin0Name_en admin0Pcode   Total_pop
# 0         PK2      Pakistan          PK    1332912.0
# 1         PK6      Pakistan          PK    1078683.0
# 2         PK6      Pakistan          PK     433517.0
# 3         PK2      Pakistan          PK     180414.0
# 4         PK6      Pakistan          PK     639748.0

# %%
city = df2['admin3Name_en'].between('Abbottabad','Alipur')	
city
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 428    False
# 429    False
# 430    False
# 431    False
# 432    False
# Name: admin3Name_en, Length: 433, dtype: bool

# %%
code = df2['admin2Pcode'].between('PK201','PK623')
code
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 428     True
# 429     True
# 430    False
# 431    False
# 432    False
# Name: admin2Pcode, Length: 433, dtype: bool

# %%
pop = df2[' Total_pop '].between(433517.0,1332912.0)
pop
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 428    False
# 429     True
# 430    False
# 431    False
# 432    False
# Name:  Total_pop , Length: 433, dtype: bool

# %%
df2[' Total_pop ']
# Out:
# 0      1332912.0
# 1      1078683.0
# 2       433517.0
# 3       180414.0
# 4       639748.0
#          ...
# 428      52291.0
# 429     614143.0
# 430     102129.0
# 431     253632.0
# 432      67861.0
# Name:  Total_pop , Length: 433, dtype: float64

# %%
final_criteria4 = city & code & pop
final_criteria4
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 428    False
# 429    False
# 430    False
# 431    False
# 432    False
# Length: 433, dtype: bool

# %%
df2[final_criteria4]
# Out:
#    admin3Name_en admin3Pcode admin2Name_en admin2Pcode       admin1Name_en  \
# 0     Abbottabad     PK20101    Abbottabad       PK201  Khyber Pakhtunkhwa
# 1  Ahmadupr East     PK60305    Bahawalpur       PK603              Punjab
# 2  Ahmedpur Sial     PK61201         Jhang       PK612              Punjab
# 4         Alipur     PK62301  Muzaffargarh       PK623              Punjab
#
#   admin1Pcode admin0Name_en admin0Pcode   Total_pop
# 0         PK2      Pakistan          PK    1332912.0
# 1         PK6      Pakistan          PK    1078683.0
# 2         PK6      Pakistan          PK     433517.0
# 4         PK6      Pakistan          PK     639748.0

# %%
final_criteria5 = city | code & pop
final_criteria5
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 428    False
# 429     True
# 430    False
# 431    False
# 432    False
# Length: 433, dtype: bool

# %%
df2[final_criteria5]
# Out:
#         admin3Name_en admin3Pcode     admin2Name_en admin2Pcode  \
# 0          Abbottabad     PK20101        Abbottabad       PK201
# 1       Ahmadupr East     PK60305        Bahawalpur       PK603
# 2       Ahmedpur Sial     PK61201             Jhang       PK612
# 3                Alai     PK20301          Batagram       PK203
# 4              Alipur     PK62301      Muzaffargarh       PK623
# 8              Attock     PK60101            Attock       PK601
# 11            Babuzai     PK22201              Swat       PK222
# 14       Bahawalnagar     PK60201      Bahawalnagar       PK602
# 15         Bahawalpur     PK60301        Bahawalpur       PK603
# 21              Bannu     PK20201             Bannu       PK202
# 23               Bara     PK23301            Khyber       PK233
# 34            Bhakkar     PK60401           Bhakkar       PK604
# 48            Chakwal     PK60501           Chakwal       PK605
# 52          Charsadda     PK20501         Charsadda       PK205
# ...

# %%
final_criteria6 = city | code | pop
final_criteria6
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 428     True
# 429     True
# 430    False
# 431    False
# 432    False
# Length: 433, dtype: bool

# %%
df2[final_criteria6]
# Out:
#      admin3Name_en admin3Pcode admin2Name_en admin2Pcode       admin1Name_en  \
# 0       Abbottabad     PK20101    Abbottabad       PK201  Khyber Pakhtunkhwa
# 1    Ahmadupr East     PK60305    Bahawalpur       PK603              Punjab
# 2    Ahmedpur Sial     PK61201         Jhang       PK612              Punjab
# 3             Alai     PK20301      Batagram       PK203  Khyber Pakhtunkhwa
# 4           Alipur     PK62301  Muzaffargarh       PK623              Punjab
# ..             ...         ...           ...         ...                 ...
# 424           Wari     PK23004     Upper Dir       PK230  Khyber Pakhtunkhwa
# 426          Wazir     PK23901      FR Bannu       PK239  Khyber Pakhtunkhwa
# 427      Wazirabad     PK60904    Gujranwala       PK609              Punjab
# 428     Yaka Ghund     PK23507       Mohmand       PK235  Khyber Pakhtunkhwa
# 429         Yazman     PK60304    Bahawalpur       PK603              Punjab
#
# ...

# %%
pop_query = df2.query('639748.0<=Total_pop<=1332912.0')
pop_query
# Out:
#       admin3Name_en admin3Pcode   admin2Name_en admin2Pcode  \
# 0        Abbottabad     PK20101      Abbottabad       PK201
# 1     Ahmadupr East     PK60305      Bahawalpur       PK603
# 4            Alipur     PK62301    Muzaffargarh       PK623
# 7         Arif Wala     PK62701       Pakpattan       PK627
# 14     Bahawalnagar     PK60201    Bahawalnagar       PK602
# ..              ...         ...             ...         ...
# 400          Taxila     PK63007      Rawalpindi       PK630
# 405       Timergara     PK21402       Lower Dir       PK214
# 406  Toba Tek Singh     PK63503  Toba Tek Singh       PK635
# 420          Vehari     PK63603          Vehari       PK636
# 427       Wazirabad     PK60904      Gujranwala       PK609
#
#           admin1Name_en admin1Pcode admin0Name_en admin0Pcode  Total_pop
# 0    Khyber Pakhtunkhwa         PK2      Pakistan          PK  1332912.0
# 1                Punjab         PK6      Pakistan          PK  1078683.0
# ...

# %%
df2[' Total_pop '] = pd.to_numeric(df2[' Total_pop '], errors='coerce')

# %%
df2.columns
# Out:
# Index(['admin3Name_en', 'admin3Pcode', 'admin2Name_en', 'admin2Pcode',
#        'admin1Name_en', 'admin1Pcode', 'admin0Name_en', 'admin0Pcode',
#        ' Total_pop '],
#       dtype='object')

# %%
df2.rename(columns={' Total_pop ': 'Total_pop'}, inplace=True)

# %%
df2['Total_pop'] = df2['Total_pop'].where(df2['Total_pop']<= 800000,800000)
df2['Total_pop']
# Out:
# 0      800000.0
# 1      800000.0
# 2      433517.0
# 3      180414.0
# 4      639748.0
#          ...
# 428     52291.0
# 429    614143.0
# 430    102129.0
# 431    253632.0
# 432     67861.0
# Name: Total_pop, Length: 433, dtype: float64

# %%
#mask
masked_pop=df2.mask(df2['Total_pop']>800000.0)
masked_pop
# Out:
#      admin3Name_en admin3Pcode admin2Name_en admin2Pcode       admin1Name_en  \
# 0       Abbottabad     PK20101    Abbottabad       PK201  Khyber Pakhtunkhwa
# 1    Ahmadupr East     PK60305    Bahawalpur       PK603              Punjab
# 2    Ahmedpur Sial     PK61201         Jhang       PK612              Punjab
# 3             Alai     PK20301      Batagram       PK203  Khyber Pakhtunkhwa
# 4           Alipur     PK62301  Muzaffargarh       PK623              Punjab
# ..             ...         ...           ...         ...                 ...
# 428     Yaka Ghund     PK23507       Mohmand       PK235  Khyber Pakhtunkhwa
# 429         Yazman     PK60304    Bahawalpur       PK603              Punjab
# 430          Zehri     PK71404       Khuzdar       PK714         Balochistan
# 431           Zhob     PK73002          Zhob       PK730         Balochistan
# 432         Ziarat     PK73102        Ziarat       PK731         Balochistan
#
# ...

# %%
masked_pop_cleaned=masked_pop.dropna(how='all')
masked_pop_cleaned
# Out:
#      admin3Name_en admin3Pcode admin2Name_en admin2Pcode       admin1Name_en  \
# 0       Abbottabad     PK20101    Abbottabad       PK201  Khyber Pakhtunkhwa
# 1    Ahmadupr East     PK60305    Bahawalpur       PK603              Punjab
# 2    Ahmedpur Sial     PK61201         Jhang       PK612              Punjab
# 3             Alai     PK20301      Batagram       PK203  Khyber Pakhtunkhwa
# 4           Alipur     PK62301  Muzaffargarh       PK623              Punjab
# ..             ...         ...           ...         ...                 ...
# 428     Yaka Ghund     PK23507       Mohmand       PK235  Khyber Pakhtunkhwa
# 429         Yazman     PK60304    Bahawalpur       PK603              Punjab
# 430          Zehri     PK71404       Khuzdar       PK714         Balochistan
# 431           Zhob     PK73002          Zhob       PK730         Balochistan
# 432         Ziarat     PK73102        Ziarat       PK731         Balochistan
#
# ...
