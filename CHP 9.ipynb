# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
mohib_names = pd.read_csv(r'C:\Users\pc\Desktop\names.csv')
mohib_names
# Out:
#        Name  Age
# 0  Cornelia   70
# 1     Abbas   69
# 2  Penelope    4
# 3      Niko    2

# %%
new_data_list = ['Aria', 1]
mohib_names.loc[4] = new_data_list
mohib_names
# Out:
#        Name  Age
# 0  Cornelia   70
# 1     Abbas   69
# 2  Penelope    4
# 3      Niko    2
# 4      Aria    1

# %%
mohib_names.loc['five'] = ['Zach', 3]
mohib_names
# Out:
#           Name  Age
# 0     Cornelia   70
# 1        Abbas   69
# 2     Penelope    4
# 3         Niko    2
# 4         Aria    1
# five      Zach    3

# %%
mohib_names.loc[len(mohib_names)] = {'Name':'Zayd', 'Age':2}
mohib_names
# Out:
#           Name  Age
# 0     Cornelia   70
# 1        Abbas   69
# 2     Penelope    4
# 3         Niko    2
# 4         Aria    1
# five      Zach    3
# 6         Zayd    2

# %%
mohib_names
# Out:
#           Name  Age
# 0     Cornelia   70
# 1        Abbas   69
# 2     Penelope    4
# 3         Niko    2
# 4         Aria    1
# five      Zach    3
# 6         Zayd    2

# %%
mohib_names.loc[len(mohib_names)] = pd.Series({'Age':32, 'Name':'Dean'})
mohib_names
# Out:
#           Name  Age
# 0     Cornelia   70
# 1        Abbas   69
# 2     Penelope    4
# 3         Niko    2
# 4         Aria    1
# five      Zach    3
# 6         Zayd    2
# 7         Dean   32

# %%
new_row = pd.DataFrame({'Name': ['Aria'], 'Age': [1]})
names = pd.read_csv(r'C:\Users\pc\Desktop\names.csv')
mohib_names2 = pd.concat([names, new_row], ignore_index=True)
mohib_names2
# Out:
#        Name  Age
# 0  Cornelia   70
# 1     Abbas   69
# 2  Penelope    4
# 3      Niko    2
# 4      Aria    1

# %%
mohib_names2 = pd.concat([names, new_row], ignore_index=True)
mohib_names2
# Out:
#        Name  Age
# 0  Cornelia   70
# 1     Abbas   69
# 2  Penelope    4
# 3      Niko    2
# 4      Aria    1

# %%
mohib_names.index = ['Canada', 'Canada', 'Canada', 'USA']

print(mohib_names)
# Out:
#             Name  Age
# Canada  Cornelia   70
# Canada     Abbas   69
# Canada  Penelope    4
# USA         Niko    2

# %%
pd.concat([mohib_names, new_row], ignore_index=True)
# Out:
#        Name  Age
# 0  Cornelia   70
# 1     Abbas   69
# 2  Penelope    4
# 3      Niko    2
# 4      Aria    1
# 5      Zach    3
# 6      Zayd    2
# 7      Dean   32
# 8      Aria    1

# %%
mohib_s = pd.Series({'Name': 'Zach', 'Age': 3}, name=len(names))
mohib_s
# Out:
# Name    Zach
# Age        3
# Name: 4, dtype: object

# %%
pd.concat([mohib_names, mohib_s], ignore_index=True)
# Out:
#        Name   Age     0
# 0  Cornelia  70.0   NaN
# 1     Abbas  69.0   NaN
# 2  Penelope   4.0   NaN
# 3      Niko   2.0   NaN
# 4      Aria   1.0   NaN
# 5      Zach   3.0   NaN
# 6      Zayd   2.0   NaN
# 7      Dean  32.0   NaN
# 8       NaN   NaN  Zach
# 9       NaN   NaN     3

# %%
s1 = pd.Series({'Name': 'Zach', 'Age': 3}, name=len(mohib_names))
s2 = pd.Series({'Name': 'Zayd', 'Age': 2}, name='USA')
pd.concat([s1, s2], ignore_index=True)
# Out:
# 0    Zach
# 1       3
# 2    Zayd
# 3       2
# dtype: object

# %%
mohib_bball_16 = pd.read_csv(r'C:\Users\pc\Desktop\baseball16.csv')
mohib_bball_16.head()
# Out:
#     playerID  yearID  stint teamID lgID    G   AB    R    H  2B  ...   RBI  \
# 0  altuvjo01    2016      1    HOU   AL  161  640  108  216  42  ...  96.0
# 1  bregmal01    2016      1    HOU   AL   49  201   31   53  13  ...  34.0
# 2  castrja01    2016      1    HOU   AL  113  329   41   69  16  ...  32.0
# 3  correca01    2016      1    HOU   AL  153  577   76  158  36  ...  96.0
# 4  gattiev01    2016      1    HOU   AL  128  447   58  112  19  ...  72.0
#
#      SB    CS  BB     SO   IBB  HBP   SH   SF  GIDP
# 0  30.0  10.0  60   70.0  11.0  7.0  3.0  7.0  15.0
# 1   2.0   0.0  15   52.0   0.0  0.0  0.0  1.0   1.0
# 2   2.0   1.0  45  123.0   0.0  1.0  1.0  0.0   9.0
# 3  13.0   3.0  75  139.0   5.0  5.0  0.0  3.0  12.0
# 4   2.0   1.0  43  127.0   6.0  4.0  0.0  5.0  12.0
#
# [5 rows x 22 columns]

# %%
data_dict = mohib_bball_16.iloc[0].to_dict()
print(data_dict)
# Out:
# {'playerID': 'altuvjo01', 'yearID': 2016, 'stint': 1, 'teamID': 'HOU', 'lgID': 'AL', 'G': 161, 'AB': 640, 'R': 108, 'H': 216, '2B': 42, '3B': 5, 'HR': 24, 'RBI': 96.0, 'SB': 30.0, 'CS': 10.0, 'BB': 60, 'SO': 70.0, 'IBB': 11.0, 'HBP': 7.0, 'SH': 3.0, 'SF': 7.0, 'GIDP': 15.0}

# %%
new_data_dict = {k: '' if isinstance(v, str) else np.nan for k, v in data_dict.items()}
print(new_data_dict)
# Out:
# {'playerID': '', 'yearID': nan, 'stint': nan, 'teamID': '', 'lgID': '', 'G': nan, 'AB': nan, 'R': nan, 'H': nan, '2B': nan, '3B': nan, 'HR': nan, 'RBI': nan, 'SB': nan, 'CS': nan, 'BB': nan, 'SO': nan, 'IBB': nan, 'HBP': nan, 'SH': nan, 'SF': nan, 'GIDP': nan}

# %%
random_data = []
for i in range(1000):
    d = dict()
    for k, v in data_dict.items():
        if isinstance(v, str):
            d[k] = np.random.choice(list('abcde'))
        else:
            d[k] = np.random.randint(10)
    random_data.append(pd.Series(d, name=i + len(mohib_bball_16)))
    
random_data[0].head()
# Out:
# playerID    a
# yearID      3
# stint       2
# teamID      c
# lgID        a
# Name: 16, dtype: object

# %%
# %%timeit
bball_16_copy = mohib_bball_16.copy()
for row in random_data:
    bball_16_copy = pd.concat([bball_16_copy, row], ignore_index=True)
# Out:
# 3.11 s ± 233 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
stocks_2016 = pd.read_csv(r'C:\Users\pc\Desktop\stocks_2016.csv', index_col='Symbol')
stocks_2017 = pd.read_csv(r'C:\Users\pc\Desktop\stocks_2017.csv', index_col='Symbol')

# %%
stocks_2016
# Out:
#         Shares  Low  High
# Symbol
# AAPL        80   95   110
# TSLA        50   80   130
# WMT         40   55    70

# %%
stocks_2017
# Out:
#         Shares  Low  High
# Symbol
# AAPL        50  120   140
# GE         100   30    40
# IBM         87   75    95
# SLB         20   55    85
# TXN        500   15    23
# TSLA       100  100   300

# %%
mohib_s_list = [stocks_2016, stocks_2017]
pd.concat(mohib_s_list)
# Out:
#         Shares  Low  High
# Symbol
# AAPL        80   95   110
# TSLA        50   80   130
# WMT         40   55    70
# AAPL        50  120   140
# GE         100   30    40
# IBM         87   75    95
# SLB         20   55    85
# TXN        500   15    23
# TSLA       100  100   300

# %%
pd.concat(mohib_s_list, keys=['2016', '2017'], names=['Year', 'Symbol'])
# Out:
#              Shares  Low  High
# Year Symbol
# 2016 AAPL        80   95   110
#      TSLA        50   80   130
#      WMT         40   55    70
# 2017 AAPL        50  120   140
#      GE         100   30    40
#      IBM         87   75    95
#      SLB         20   55    85
#      TXN        500   15    23
#      TSLA       100  100   300

# %%
pd.concat(mohib_s_list, keys=['2016', '2017'], axis='columns', names=['Year', None])
# Out:
# Year     2016                2017
#        Shares   Low   High Shares    Low   High
# Symbol
# AAPL     80.0  95.0  110.0   50.0  120.0  140.0
# TSLA     50.0  80.0  130.0  100.0  100.0  300.0
# WMT      40.0  55.0   70.0    NaN    NaN    NaN
# GE        NaN   NaN    NaN  100.0   30.0   40.0
# IBM       NaN   NaN    NaN   87.0   75.0   95.0
# SLB       NaN   NaN    NaN   20.0   55.0   85.0
# TXN       NaN   NaN    NaN  500.0   15.0   23.0

# %%
pd.concat(mohib_s_list, join='inner', keys=['2016', '2017'], axis='columns', names=['Year', None])
# Out:
# Year     2016            2017
#        Shares Low High Shares  Low High
# Symbol
# AAPL       80  95  110     50  120  140
# TSLA       50  80  130    100  100  300

# %%
pd.concat([stocks_2016,stocks_2017], ignore_index=True)
# Out:
#    Shares  Low  High
# 0      80   95   110
# 1      50   80   130
# 2      40   55    70
# 3      50  120   140
# 4     100   30    40
# 5      87   75    95
# 6      20   55    85
# 7     500   15    23
# 8     100  100   300

# %%
stocks_2015 = stocks_2016.copy()

# %%
stocks_2017
# Out:
#         Shares  Low  High
# Symbol
# AAPL        50  120   140
# GE         100   30    40
# IBM         87   75    95
# SLB         20   55    85
# TXN        500   15    23
# TSLA       100  100   300

# %%
from IPython.display import display_html

years = 2016, 2017, 2018
stock_tables = [
    pd.read_csv(r'C:\Users\pc\Desktop\slb_stock.csv').assign(Year=year)
    for year in years
]

def display_frames(frames, num_spaces=0):
    t_style = '<table style="display: inline;"'
    tables_html = [df.to_html().replace('<table', t_style) for df in frames]

    space = '&nbsp;' * num_spaces
    display_html(space.join(tables_html), raw=True)

# Display the frames
display_frames(stock_tables, 30)

# Assign the individual dataframes to variables
stocks_2016, stocks_2017, stocks_2018 = stock_tables
# Out:
# <table style="display: inline;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Volume</th>
#       <th>Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2010-01-04</td>
#       <td>66.39</td>
#       <td>67.20</td>
#       <td>66.12</td>
#       <td>67.11</td>
#       <td>5771234</td>
#       <td>2016</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2010-01-05</td>
#       <td>66.99</td>
#       <td>67.62</td>
#       <td>66.73</td>
#       <td>67.30</td>
#       <td>7366270</td>
#       <td>2016</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2010-01-06</td>
#       <td>67.17</td>
#       <td>68.94</td>
#       <td>67.03</td>
#       <td>68.80</td>
#       <td>9949946</td>
#       <td>2016</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %%
pd.concat(stock_tables, keys=[2016, 2017, 2018])
# Out:
#                  Date   Open   High    Low  Close    Volume  Year
# 2016 0     2010-01-04  66.39  67.20  66.12  67.11   5771234  2016
#      1     2010-01-05  66.99  67.62  66.73  67.30   7366270  2016
#      2     2010-01-06  67.17  68.94  67.03  68.80   9949946  2016
#      3     2010-01-07  68.49  69.81  68.21  69.51   7700297  2016
#      4     2010-01-08  69.19  72.00  69.09  70.65  13487621  2016
# ...               ...    ...    ...    ...    ...       ...   ...
# 2018 1890  2017-07-10  64.82  65.68  64.78  65.35   5873639  2018
#      1891  2017-07-11  65.35  66.24  65.07  65.79   5534042  2018
#      1892  2017-07-12  66.52  66.60  65.34  65.58   6497554  2018
#      1893  2017-07-13  65.47  66.54  65.44  66.49   6252255  2018
#      1894  2017-07-14  66.50  67.09  66.37  66.85   5340611  2018
#
# [5685 rows x 7 columns]

# %%
pd.concat(dict(zip(years,stock_tables)), axis='columns')
# Out:
#             2016                                                    2017  \
#             Date   Open   High    Low  Close    Volume  Year        Date
# 0     2010-01-04  66.39  67.20  66.12  67.11   5771234  2016  2010-01-04
# 1     2010-01-05  66.99  67.62  66.73  67.30   7366270  2016  2010-01-05
# 2     2010-01-06  67.17  68.94  67.03  68.80   9949946  2016  2010-01-06
# 3     2010-01-07  68.49  69.81  68.21  69.51   7700297  2016  2010-01-07
# 4     2010-01-08  69.19  72.00  69.09  70.65  13487621  2016  2010-01-08
# ...          ...    ...    ...    ...    ...       ...   ...         ...
# 1890  2017-07-10  64.82  65.68  64.78  65.35   5873639  2016  2017-07-10
# 1891  2017-07-11  65.35  66.24  65.07  65.79   5534042  2016  2017-07-11
# 1892  2017-07-12  66.52  66.60  65.34  65.58   6497554  2016  2017-07-12
# 1893  2017-07-13  65.47  66.54  65.44  66.49   6252255  2016  2017-07-13
# 1894  2017-07-14  66.50  67.09  66.37  66.85   5340611  2016  2017-07-14
#
# ...

# %%
stocks_2016.join(stocks_2017, lsuffix='_2016', rsuffix='_2017', how='outer')
# Out:
#        Date_2016  Open_2016  High_2016  Low_2016  Close_2016  Volume_2016  \
# 0     2010-01-04      66.39      67.20     66.12       67.11      5771234
# 1     2010-01-05      66.99      67.62     66.73       67.30      7366270
# 2     2010-01-06      67.17      68.94     67.03       68.80      9949946
# 3     2010-01-07      68.49      69.81     68.21       69.51      7700297
# 4     2010-01-08      69.19      72.00     69.09       70.65     13487621
# ...          ...        ...        ...       ...         ...          ...
# 1890  2017-07-10      64.82      65.68     64.78       65.35      5873639
# 1891  2017-07-11      65.35      66.24     65.07       65.79      5534042
# 1892  2017-07-12      66.52      66.60     65.34       65.58      6497554
# 1893  2017-07-13      65.47      66.54     65.44       66.49      6252255
# 1894  2017-07-14      66.50      67.09     66.37       66.85      5340611
#
#       Year_2016   Date_2017  Open_2017  High_2017  Low_2017  Close_2017  \
# ...

# %%
stocks_2016
# Out:
#             Date   Open   High    Low  Close    Volume  Year
# 0     2010-01-04  66.39  67.20  66.12  67.11   5771234  2016
# 1     2010-01-05  66.99  67.62  66.73  67.30   7366270  2016
# 2     2010-01-06  67.17  68.94  67.03  68.80   9949946  2016
# 3     2010-01-07  68.49  69.81  68.21  69.51   7700297  2016
# 4     2010-01-08  69.19  72.00  69.09  70.65  13487621  2016
# ...          ...    ...    ...    ...    ...       ...   ...
# 1890  2017-07-10  64.82  65.68  64.78  65.35   5873639  2016
# 1891  2017-07-11  65.35  66.24  65.07  65.79   5534042  2016
# 1892  2017-07-12  66.52  66.60  65.34  65.58   6497554  2016
# 1893  2017-07-13  65.47  66.54  65.44  66.49   6252255  2016
# 1894  2017-07-14  66.50  67.09  66.37  66.85   5340611  2016
#
# [1895 rows x 7 columns]

# %%
other = [stocks_2017.add_suffix('_2017'), stocks_2018.add_suffix('_2018')]
stocks_2016.add_suffix('_2016').join(other, how='outer')
# Out:
#        Date_2016  Open_2016  High_2016  Low_2016  Close_2016  Volume_2016  \
# 0     2010-01-04      66.39      67.20     66.12       67.11      5771234
# 1     2010-01-05      66.99      67.62     66.73       67.30      7366270
# 2     2010-01-06      67.17      68.94     67.03       68.80      9949946
# 3     2010-01-07      68.49      69.81     68.21       69.51      7700297
# 4     2010-01-08      69.19      72.00     69.09       70.65     13487621
# ...          ...        ...        ...       ...         ...          ...
# 1890  2017-07-10      64.82      65.68     64.78       65.35      5873639
# 1891  2017-07-11      65.35      66.24     65.07       65.79      5534042
# 1892  2017-07-12      66.52      66.60     65.34       65.58      6497554
# 1893  2017-07-13      65.47      66.54     65.44       66.49      6252255
# 1894  2017-07-14      66.50      67.09     66.37       66.85      5340611
#
#       Year_2016   Date_2017  Open_2017  High_2017  ...  Close_2017  \
# ...

# %%
stock_join = stocks_2016.add_suffix('_2016').join(other, how='outer')
stock_concat = pd.concat(dict(zip(years,stock_tables)), axis='columns')

# %%
stock_concat.columns = stock_concat.columns.get_level_values(1) + '_' + \
                            stock_concat.columns.get_level_values(0).astype(str)

# %%
stock_concat
# Out:
#        Date_2016  Open_2016  High_2016  Low_2016  Close_2016  Volume_2016  \
# 0     2010-01-04      66.39      67.20     66.12       67.11      5771234
# 1     2010-01-05      66.99      67.62     66.73       67.30      7366270
# 2     2010-01-06      67.17      68.94     67.03       68.80      9949946
# 3     2010-01-07      68.49      69.81     68.21       69.51      7700297
# 4     2010-01-08      69.19      72.00     69.09       70.65     13487621
# ...          ...        ...        ...       ...         ...          ...
# 1890  2017-07-10      64.82      65.68     64.78       65.35      5873639
# 1891  2017-07-11      65.35      66.24     65.07       65.79      5534042
# 1892  2017-07-12      66.52      66.60     65.34       65.58      6497554
# 1893  2017-07-13      65.47      66.54     65.44       66.49      6252255
# 1894  2017-07-14      66.50      67.09     66.37       66.85      5340611
#
#       Year_2016   Date_2017  Open_2017  High_2017  ...  Close_2017  \
# ...

# %%
step1 = stocks_2016.merge(stocks_2017, left_index=True, right_index=True, 
                          how='outer', suffixes=('_2016', '_2017'))
stock_merge = step1.merge(stocks_2018.add_suffix('_2018'), 
                          left_index=True, right_index=True, how='outer')

stock_concat.equals(stock_merge)
# Out:
# True

# %%
names = ['prices', 'transactions']
food_tables = [pd.read_csv(r'C:\Users\pc\Desktop\food_transactions.csv'.format(name)) for name in names]
food_prices, food_transactions = food_tables
display_frames(food_tables, 30)
# Out:
# <table style="display: inline;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>custid</th>
#       <th>item</th>
#       <th>store</th>
#       <th>quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>pear</td>
#       <td>A</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>banana</td>
#       <td>A</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>steak</td>
#       <td>B</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>pear</td>
#       <td>B</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>peach</td>
#       <td>B</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>steak</td>
#       <td>B</td>
#       <td>1</td>
#     </tr>
# ...

# %%
food_transactions.merge(food_prices, on=['item', 'store'])
# Out:
#    custid_x     item store  quantity_x  custid_y  quantity_y
# 0         1     pear     A           5         1           5
# 1         1   banana     A          10         1          10
# 2         2    steak     B           3         2           3
# 3         2    steak     B           3         2           1
# 4         2     pear     B           1         2           1
# 5         2    peach     B           2         2           2
# 6         2    steak     B           1         2           3
# 7         2    steak     B           1         2           1
# 8         2  coconut     B           4         2           4

# %%
food_prices = pd.read_csv(r'C:\Users\pc\Desktop\food_prices.csv')
food_transactions.merge(food_prices.query('Date == 2017'), how='left')
# Out:
#    custid     item store  quantity  price    Date
# 0       1     pear     A         5   0.99  2017.0
# 1       1   banana     A        10   0.39  2017.0
# 2       2    steak     B         3   6.99  2017.0
# 3       2     pear     B         1   1.99  2017.0
# 4       2    peach     B         2   3.49  2017.0
# 5       2    steak     B         1   6.99  2017.0
# 6       2  coconut     B         4    NaN     NaN

# %%
food_prices_join = food_prices.query('Date == 2017').set_index(['item', 'store'])
food_prices_join
# Out:
#               price  Date
# item   store
# pear   A       0.99  2017
#        B       1.99  2017
# peach  A       2.99  2017
#        B       3.49  2017
# banana A       0.39  2017
#        B       0.49  2017
# steak  A       5.99  2017
#        B       6.99  2017

# %%
food_transactions.join(food_prices_join, on=['item', 'store'])
# Out:
#    custid     item store  quantity  price    Date
# 0       1     pear     A         5   0.99  2017.0
# 1       1   banana     A        10   0.39  2017.0
# 2       2    steak     B         3   6.99  2017.0
# 3       2     pear     B         1   1.99  2017.0
# 4       2    peach     B         2   3.49  2017.0
# 5       2    steak     B         1   6.99  2017.0
# 6       2  coconut     B         4    NaN     NaN

# %%
food_transactions = pd.read_csv(r'C:\Users\pc\Desktop\food_transactions.csv')

# %%
from sqlalchemy import create_engine
engine = create_engine(r'sqlite:///C:\Users\pc\Desktop\chinook.db')

# %%
tracks = pd.read_sql_table('tracks', engine)
tracks.head()
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                               None        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice
# 0  11170334       0.99
# ...

# %%
import pandas as pd

# %%
mohib_genres = pd.read_sql_table('genres', engine)
mohib_genres.head()
# Out:
#    GenreId                Name
# 0        1                Rock
# 1        2                Jazz
# 2        3               Metal
# 3        4  Alternative & Punk
# 4        5       Rock And Roll

# %%
genre_track = mohib_genres.merge(tracks[['GenreId', 'Milliseconds']], 
                           on='GenreId', how='left') \
                     .drop('GenreId', axis='columns')
genre_track.head()
# Out:
#    Name  Milliseconds
# 0  Rock        343719
# 1  Rock        342562
# 2  Rock        230619
# 3  Rock        252051
# 4  Rock        375418

# %%
genre_time = genre_track.groupby('Name')['Milliseconds'].mean()
pd.to_timedelta(genre_time, unit='ms').dt.floor('s').sort_values()
# Out:
# Name
# Rock And Roll        0 days 00:02:14
# Opera                0 days 00:02:54
# Hip Hop/Rap          0 days 00:02:58
# Easy Listening       0 days 00:03:09
# Bossa Nova           0 days 00:03:39
# R&B/Soul             0 days 00:03:40
# World                0 days 00:03:44
# Pop                  0 days 00:03:49
# Latin                0 days 00:03:52
# Alternative & Punk   0 days 00:03:54
# Soundtrack           0 days 00:04:04
# Reggae               0 days 00:04:07
# Alternative          0 days 00:04:24
# Blues                0 days 00:04:30
# Rock                 0 days 00:04:43
# Jazz                 0 days 00:04:51
# Classical            0 days 00:04:53
# Heavy Metal          0 days 00:04:57
# Electronica/Dance    0 days 00:05:02
# Metal                0 days 00:05:09
# Comedy               0 days 00:26:25
# TV Shows             0 days 00:35:45
# Drama                0 days 00:42:55
# Science Fiction      0 days 00:43:45
# Sci Fi & Fantasy     0 days 00:48:31
# ...

# %%
cust = pd.read_sql_table('customers', engine, 
                         columns=['CustomerId', 'FirstName', 'LastName'])
invoice = pd.read_sql_table('invoices', engine, 
                            columns=['InvoiceId','CustomerId'])
ii = pd.read_sql_table('invoice_items', engine, 
                       columns=['InvoiceId', 'UnitPrice', 'Quantity'])

# %%
mohib_cust_inv = cust.merge(invoice, on='CustomerId') \
               .merge(ii, on='InvoiceId')
mohib_cust_inv.head()
# Out:
#    CustomerId FirstName   LastName  InvoiceId  UnitPrice  Quantity
# 0           1      Luís  Gonçalves         98       1.99         1
# 1           1      Luís  Gonçalves         98       1.99         1
# 2           1      Luís  Gonçalves        121       0.99         1
# 3           1      Luís  Gonçalves        121       0.99         1
# 4           1      Luís  Gonçalves        121       0.99         1

# %%
total = mohib_cust_inv['Quantity'] * mohib_cust_inv['UnitPrice']
mohib_cols = ['CustomerId', 'FirstName', 'LastName']
mohib_cust_inv.assign(Total = total).groupby(mohib_cols)['Total'] \
                                  .sum() \
                                  .sort_values(ascending=False).head()
# Out:
# CustomerId  FirstName  LastName
# 6           Helena     Holý          49.62
# 26          Richard    Cunningham    47.62
# 57          Luis       Rojas         46.62
# 45          Ladislav   Kovács        45.62
# 46          Hugh       O'Reilly      45.62
# Name: Total, dtype: float64

# %%
pd.read_sql_query('select * from tracks limit 5', engine)
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                               None        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice
# 0  11170334       0.99
# ...

# %%
sql_string1 = '''
select 
    Name, 
    time(avg(Milliseconds) / 1000, 'unixepoch') as avg_time
from (
        select 
            g.Name, 
            t.Milliseconds
        from 
            genres as g 
        join
            tracks as t
            on 
                g.genreid == t.genreid
    )
group by 
    Name
order by 
    avg_time
'''
pd.read_sql_query(sql_string1, engine)
# Out:
#                   Name  avg_time
# 0        Rock And Roll  00:02:14
# 1                Opera  00:02:54
# 2          Hip Hop/Rap  00:02:58
# 3       Easy Listening  00:03:09
# 4           Bossa Nova  00:03:39
# 5             R&B/Soul  00:03:40
# 6                World  00:03:44
# 7                  Pop  00:03:49
# 8                Latin  00:03:52
# 9   Alternative & Punk  00:03:54
# 10          Soundtrack  00:04:04
# 11              Reggae  00:04:07
# 12         Alternative  00:04:24
# 13               Blues  00:04:30
# 14                Rock  00:04:43
# 15                Jazz  00:04:51
# 16           Classical  00:04:53
# 17         Heavy Metal  00:04:57
# 18   Electronica/Dance  00:05:02
# 19               Metal  00:05:09
# 20              Comedy  00:26:25
# 21            TV Shows  00:35:45
# 22               Drama  00:42:55
# 23     Science Fiction  00:43:45
# 24    Sci Fi & Fantasy  00:48:31

# %%
sql_string2 = '''
select 
      c.customerid, 
      c.FirstName, 
      c.LastName, 
      sum(ii.quantity *  ii.unitprice) as Total
from
     customers as c
join
     invoices as i
          on c.customerid = i.customerid
join
    invoice_items as ii
          on i.invoiceid = ii.invoiceid
group by
    c.customerid, c.FirstName, c.LastName
order by
    Total desc
'''
pd.read_sql_query(sql_string2, engine)
# Out:
#     CustomerId  FirstName      LastName  Total
# 0            6     Helena          Holý  49.62
# 1           26    Richard    Cunningham  47.62
# 2           57       Luis         Rojas  46.62
# 3           45   Ladislav        Kovács  45.62
# 4           46       Hugh      O'Reilly  45.62
# 5           24      Frank       Ralston  43.62
# 6           28      Julia       Barnett  43.62
# 7           37       Fynn    Zimmermann  43.62
# 8            7     Astrid        Gruber  42.62
# 9           25     Victor       Stevens  42.62
# 10          44      Terhi    Hämäläinen  41.62
# 11           5  František   Wichterlová  40.62
# 12          43   Isabelle       Mercier  40.62
# 13          48   Johannes  Van der Berg  40.62
# 14           1       Luís     Gonçalves  39.62
# 15           3   François      Tremblay  39.62
# 16           4      Bjørn        Hansen  39.62
# 17          17       Jack         Smith  39.62
# 18          20        Dan        Miller  39.62
# ...

# %%
import pandas as pd
base_url = 'https://www.presidency.ucsb.edu/statistics/data/donald-j-trump-public-approval'
mohib_df_list = pd.read_html(base_url)
len(mohib_df_list)
# Out:
# 1

# %%
mohib_df0 = mohib_df_list[0]
mohib_df0.shape
# Out:
# (143, 5)

# %%
mohib_df0.head(7)
# Out:
#    Start Date    End Date  Approving  Disapproving  Unsure/NoData
# 0  01/04/2021  01/15/2021       34.0          62.0            4.0
# 1  12/01/2020  12/17/2020       39.0          57.0            4.0
# 2  11/05/2020  11/19/2020       43.0          55.0            2.0
# 3  10/16/2020  10/27/2020       46.0          52.0            2.0
# 4  09/30/2020  10/15/2020       43.0          55.0            2.0
# 5  09/14/2020  09/28/2020       46.0          52.0            2.0
# 6  08/31/2020  09/13/2020       42.0          56.0            2.0

# %%
trump = mohib_df_list[0]
trump.shape
# Out:
# (143, 5)

# %%
trump.head(8)
# Out:
#    Start Date    End Date  Approving  Disapproving  Unsure/NoData
# 0  01/04/2021  01/15/2021       34.0          62.0            4.0
# 1  12/01/2020  12/17/2020       39.0          57.0            4.0
# 2  11/05/2020  11/19/2020       43.0          55.0            2.0
# 3  10/16/2020  10/27/2020       46.0          52.0            2.0
# 4  09/30/2020  10/15/2020       43.0          55.0            2.0
# 5  09/14/2020  09/28/2020       46.0          52.0            2.0
# 6  08/31/2020  09/13/2020       42.0          56.0            2.0
# 7  07/30/2020  08/12/2020       42.0          55.0            3.0

# %%
df_list = pd.read_html(base_url, match='Start Date')
len(df_list)
# Out:
# 1

# %%
trump = trump.dropna(axis=1, how='all')
trump.head()
# Out:
#    Start Date    End Date  Approving  Disapproving  Unsure/NoData
# 0  01/04/2021  01/15/2021       34.0          62.0            4.0
# 1  12/01/2020  12/17/2020       39.0          57.0            4.0
# 2  11/05/2020  11/19/2020       43.0          55.0            2.0
# 3  10/16/2020  10/27/2020       46.0          52.0            2.0
# 4  09/30/2020  10/15/2020       43.0          55.0            2.0

# %%
trump.isnull().sum()
# Out:
# Start Date       2
# End Date         2
# Approving        2
# Disapproving     2
# Unsure/NoData    2
# dtype: int64

# %%
trump = trump.ffill()
trump.head()
# Out:
#    Start Date    End Date  Approving  Disapproving  Unsure/NoData
# 0  01/04/2021  01/15/2021       34.0          62.0            4.0
# 1  12/01/2020  12/17/2020       39.0          57.0            4.0
# 2  11/05/2020  11/19/2020       43.0          55.0            2.0
# 3  10/16/2020  10/27/2020       46.0          52.0            2.0
# 4  09/30/2020  10/15/2020       43.0          55.0            2.0

# %%
trump = trump.dropna(axis=1, how='all')
trump.head()
# Out:
#    Start Date    End Date  Approving  Disapproving  Unsure/NoData
# 0  01/04/2021  01/15/2021       34.0          62.0            4.0
# 1  12/01/2020  12/17/2020       39.0          57.0            4.0
# 2  11/05/2020  11/19/2020       43.0          55.0            2.0
# 3  10/16/2020  10/27/2020       46.0          52.0            2.0
# 4  09/30/2020  10/15/2020       43.0          55.0            2.0

# %%
trump.isnull().sum()
# Out:
# Start Date       0
# End Date         0
# Approving        0
# Disapproving     0
# Unsure/NoData    0
# dtype: int64

# %%
trump = trump.ffill()
trump.head()
# Out:
#    Start Date    End Date  Approving  Disapproving  Unsure/NoData
# 0  01/04/2021  01/15/2021       34.0          62.0            4.0
# 1  12/01/2020  12/17/2020       39.0          57.0            4.0
# 2  11/05/2020  11/19/2020       43.0          55.0            2.0
# 3  10/16/2020  10/27/2020       46.0          52.0            2.0
# 4  09/30/2020  10/15/2020       43.0          55.0            2.0

# %%
trump.dtypes
# Out:
# Start Date        object
# End Date          object
# Approving        float64
# Disapproving     float64
# Unsure/NoData    float64
# dtype: object

# %%
base_url = 'https://www.presidency.ucsb.edu/statistics/data/donald-j-trump-public-approval'
obama = pd.read_html(base_url)
len(obama)
# Out:
# 1

# %%
import pandas as pd

urls = [
    "https://www.presidency.ucsb.edu/statistics/data/george-bush-public-approval",
    "https://www.presidency.ucsb.edu/statistics/data/william-j-clinton-public-approval",
    "https://www.presidency.ucsb.edu/statistics/data/george-w-bush-public-approval",
    "https://www.presidency.ucsb.edu/statistics/data/barack-obama-public-approval",
    "https://www.presidency.ucsb.edu/statistics/data/donald-j-trump-public-approval"
]

dataframes = []

for url in urls:
    tables = pd.read_html(url)  
    dataframes.append(tables[0])  

gbush = dataframes[0]
clinton = dataframes[1]
gwbush = dataframes[2]
obama = dataframes[3]
trump = dataframes[4]

# %%
presidents = [gbush, clinton, gwbush, obama, trump]
df_list = pd.concat(presidents)
df_list
# Out:
#      Start Date    End Date  Approving  Disapproving  Unsure/NoData
# 0    01/08/1993  01/11/1993       56.0          37.0            7.0
# 1    12/18/1992  12/20/1992       49.0          41.0           10.0
# 2    12/04/1992  12/06/1992       49.0          47.0            4.0
# 3    11/20/1992  11/22/1992       43.0          46.0           11.0
# 4    10/13/1992  10/15/1992       34.0          56.0           10.0
# ..          ...         ...        ...           ...            ...
# 138  02/06/2017  02/12/2017       41.0          53.0            6.0
# 139  01/30/2017  02/05/2017       43.0          52.0            5.0
# 140  01/20/2017  01/29/2017       45.0          47.0            8.0
# 141         NaN         NaN        NaN           NaN            NaN
# 142         NaN         NaN        NaN           NaN            NaN
#
# [1173 rows x 5 columns]

# %%
gbush
# Out:
#      Start Date    End Date  Approving  Disapproving  Unsure/NoData
# 0    01/08/1993  01/11/1993         56            37              7
# 1    12/18/1992  12/20/1992         49            41             10
# 2    12/04/1992  12/06/1992         49            47              4
# 3    11/20/1992  11/22/1992         43            46             11
# 4    10/13/1992  10/15/1992         34            56             10
# ..          ...         ...        ...           ...            ...
# 108  05/04/1989  05/07/1989         56            22             22
# 109  04/10/1989  04/16/1989         58            16             26
# 110  03/10/1989  03/13/1989         56            16             28
# 111  02/28/1989  03/02/1989         63            13             24
# 112  01/24/1989  01/26/1989         51             6             43
#
# [113 rows x 5 columns]

# %%
clinton
# Out:
#      Start Date    End Date  Approving  Disapproving  Unsure/NoData
# 0    01/10/2001  01/14/2001         66            29              5
# 1    01/05/2001  01/07/2001         65            31              4
# 2    12/15/2000  12/17/2000         66            32              2
# 3    12/02/2000  12/04/2000         60            35              5
# 4    11/13/2000  11/15/2000         63            33              4
# ..          ...         ...        ...           ...            ...
# 211  03/12/1993  03/14/1993         53            34             13
# 212  02/26/1993  02/28/1993         59            29             12
# 213  02/12/1993  02/14/1993         51            34             15
# 214  01/29/1993  01/31/1993         54            30             16
# 215  01/24/1993  01/26/1993         58            20             22
#
# [216 rows x 5 columns]

# %%
obama.head()
# Out:
#    Start Date    End Date  Approving  Disapproving  Unsure/NoData
# 0  01/16/2017  01/19/2017       59.0          37.0            4.0
# 1  01/09/2017  01/15/2017       57.0          39.0            4.0
# 2  01/02/2017  01/08/2017       55.0          42.0            3.0
# 3  12/26/2016  01/01/2017       55.0          40.0            5.0
# 4  12/19/2016  12/25/2016       56.0          40.0            4.0
